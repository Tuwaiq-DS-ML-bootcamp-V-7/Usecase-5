# %%
#Import all relevant libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore
from convertdate import islamic
from datetime import datetime
from hijri_converter import convert

## This statement allows the visuals to render within your Jupyter Notebook.
# %matplotlib inline

# %% [markdown]
# ## Loading the data
# We can now load the dataset into pandas using the read_csv() function. This converts the CSV file into a Pandas dataframe.

# %%
#Read in the csv file and convert to a Pandas dataframe
df = pd.read_csv("Jadarat_data.csv")

# %% [markdown]
# ### Viewing the dataframe
# We can get a quick sense of the size of our dataset by using the shape method. This returns a tuple with the number of rows and columns in the dataset.

# %%
df
# Out:
#                       job_title    job_date  \
# 0                         محاسب  27/05/1444
# 1                          بائع  27/05/1444
# 2     أخصائي عمليات موارد بشرية  27/05/1444
# 3               ميكانيكي سيارات  27/05/1444
# 4                         محاسب  27/05/1444
# ...                         ...         ...
# 1465        مهندس تقنية معلومات  19/06/1444
# 1466                     سكرتير  19/06/1444
# 1467                      صيدلي  18/06/1444
# 1468        مشغل آلة تشطيب رخام  18/06/1444
# 1469                      صيدلي  18/06/1444
#
#                                                job_desc  \
# 0     ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
# 1     ['بيع مجموعة من السلع والخدمات للعملاء، وتوفير...
# 2     ['تنفيذ الإجراءات والأنظمة والنماذج الخاصة بمر...
# 3     ['تشخيص أعطال السيارات وإصلاحها وتنفيذ برامج ا...
# 4     ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
# ...                                                 ...
# 1465  ['دراسة احتياجات العميل من الأجهزة الحاسوبية و...
# 1466  ['دعم المدير أو الإدارة من خلال كتابة الوثائق ...
# 1467  ['دراسة التركيبات الدوائية للعقاقير والعلاجات ...
# 1468  ['تشغيل آلة تشطيب الرخام وابعادء الأجزاء المتف...
# 1469  ['دراسة التركيبات الدوائية للعقاقير والعلاجات ...
#
#                                               job_tasks  \
# 0     ['   تدقيق المطالبات المالية والتأكد من اكتمال...
# 1     ['   بيع مجموعة من السلع والخدمات للعملاء.', '...
# 2     ['   تنفيذ الإجراءات والأنظمة والنماذج الخاصة ...
# 3     ['   فحص أداء المعدّات الكهربائية والميكانيكية...
# 4     ['   تدقيق المطالبات المالية والتأكد من اكتمال...
# ...                                                 ...
# 1465  ['   متابعة وتقييم عملية جمع وتحليل المعطيات و...
# 1466  ['   تدوين الملاحظات، التي يتم إملاؤها، بطريقة...
# 1467  ['   دراسة مواصفات وتركيبات الادوية والعقاقير ...
# 1468  ['   تسوية الرخام بواسطة أقراص الألماس الحديدي...
# 1469  ['   دراسة مواصفات وتركيبات الادوية والعقاقير ...
#
#                                               comp_name     comp_no comp_type  \
# 0                              شركة مقر العالم للسفريات    1-317262       خاص
# 1                          شركة عالم الكهرباء للمقاولات   4-1324428       خاص
# 2                                       شركه دار السلام    1-155294       خاص
# 3                               مؤسسة لمكو لغيار الزيوت   8-1925495       خاص
# 4                          مؤسسة فكرة اليمامة للمقاولات   1-2356639       خاص
# ...                                                 ...         ...       ...
# 1465                  مطعم الاوراق الخضر لتقديم الوجبات  15-1698448       خاص
# 1466         شركة ملتقى التجار لحاضنات و مسرعات الأعمال   9-2013930       خاص
# 1467                شركة تقنية الدواجن والألبان للتجارة   1-2415250       خاص
# 1468  مصنع عبدالرحمن بن محمد بن عبدالعزيز العبدالقاد...  15-1971895       خاص
# 1469                شركة تقنية الدواجن والألبان للتجارة   1-2415250       خاص
#
#          comp_size                                       eco_activity  \
# 0     متوسطة فئة أ                        أنشطة وكالات السياحة والسفر
# 1     متوسطة فئة ب  تركيب انظمة التبريد وتكييف الهواء وصيانتها واص...
# 2     متوسطة فئة أ               ترميمات المباني السكنية والغير سكنية
# 3      صغيرة فئة ب                                                NaN
# 4            كبيرة                   الإنشاءات العامة للمباني السكنية
# ...            ...                                                ...
# 1465   صغيرة فئة ب                                  المطاعم مع الخدمة
# 1466   صغيرة فئة ب                       أنشطة حاضنات ومسرعات الأعمال
# 1467   صغيرة فئة ب                                                NaN
# 1468   صغيرة فئة أ                                                NaN
# 1469   صغيرة فئة ب                                                NaN
#
#                                                  qualif           region  \
# 0        ['Language data', 'اللغة الانجليزية', 'محترف']           الرياض
# 1                                                   NaN  المنطقة الشرقية
# 2              ['Language data', 'الانجليزيه', 'محترف']           الرياض
# 3     ['Skill data', 'صيانة السيارات وتقييم الاعطال'...  المنطقة الشرقية
# 4     ['Skill data', 'تحمل ضغط العمل', 'محترف', 'Lan...           الرياض
# ...                                                 ...              ...
# 1465                                                NaN           الرياض
# 1466  ['Skill data', 'فن التواصل', 'محترف', 'Languag...      مكة المكرمة
# 1467  ['Professional certificate \\ License data', '...           الرياض
# 1468  ['Skill data', 'متقن للعمل وشغوف ويرغب بالتطور...  المنطقة الشرقية
# 1469  ['Professional certificate \\ License data', '...           الرياض
#
#               city                                           benefits  \
# 0     AR RIYADH...                               ['Salary', '5000.0']
# 1     AD DAMMAM...                               ['Salary', '5000.0']
# 2     ATH THUMA...                               ['Salary', '4000.0']
# 3      AL HUFUF...                               ['Salary', '5000.0']
# 4     AR RIYADH...                               ['Salary', '5000.0']
# ...            ...                                                ...
# 1465  AR RIYADH...                               ['Salary', '5500.0']
# 1466     JEDDAH...                               ['Salary', '4000.0']
# 1467  AR RIYADH...                               ['Salary', '7000.0']
# 1468  AL KHUBAR...  ['Salary', '4000.0', 'Benefits', 'اجازة سنوية ...
# 1469  AR RIYADH...                               ['Salary', '7000.0']
#
#        contract positions     job_post_id    exper gender
# 0     دوام كامل     0 / 1  20202026350419  0 Years   both
# 1     دوام كامل     0 / 3  20202026350389  0 Years   both
# 2     دوام كامل     0 / 2  20202026350347  2 Years   both
# 3     دوام كامل    0 / 10  20202026350219  0 Years      M
# 4     دوام كامل     0 / 1  20202026350043  0 Years   both
# ...         ...       ...             ...      ...    ...
# 1465  دوام كامل     0 / 1  20202026400353  0 Years   both
# 1466  دوام كامل     0 / 1  20202026399849  2 Years   both
# 1467  دوام كامل     0 / 1  20202026399061  0 Years   both
# 1468  دوام كامل     0 / 3  20202026398972  0 Years      M
# 1469  دوام كامل     0 / 1  20202026399061  0 Years   both
#
# [1470 rows x 18 columns]

# %% [markdown]
# ## 1. Data Profiling:
# Data profiling is a comprehensive process of examining the data available in an existing dataset and collecting statistics and information about that data.

# %%
df.info
# Out:
# <bound method DataFrame.info of                       job_title    job_date  \
# 0                         محاسب  27/05/1444
# 1                          بائع  27/05/1444
# 2     أخصائي عمليات موارد بشرية  27/05/1444
# 3               ميكانيكي سيارات  27/05/1444
# 4                         محاسب  27/05/1444
# ...                         ...         ...
# 1465        مهندس تقنية معلومات  19/06/1444
# 1466                     سكرتير  19/06/1444
# 1467                      صيدلي  18/06/1444
# 1468        مشغل آلة تشطيب رخام  18/06/1444
# 1469                      صيدلي  18/06/1444
#
#                                                job_desc  \
# 0     ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
# 1     ['بيع مجموعة من السلع والخدمات للعملاء، وتوفير...
# 2     ['تنفيذ الإجراءات والأنظمة والنماذج الخاصة بمر...
# 3     ['تشخيص أعطال السيارات وإصلاحها وتنفيذ برامج ا...
# 4     ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
# ...                                                 ...
# 1465  ['دراسة احتياجات العميل من الأجهزة الحاسوبية و...
# 1466  ['دعم المدير أو الإدارة من خلال كتابة الوثائق ...
# 1467  ['دراسة التركيبات الدوائية للعقاقير والعلاجات ...
# 1468  ['تشغيل آلة تشطيب الرخام وابعادء الأجزاء المتف...
# 1469  ['دراسة التركيبات الدوائية للعقاقير والعلاجات ...
#
#                                               job_tasks  \
# 0     ['   تدقيق المطالبات المالية والتأكد من اكتمال...
# 1     ['   بيع مجموعة من السلع والخدمات للعملاء.', '...
# 2     ['   تنفيذ الإجراءات والأنظمة والنماذج الخاصة ...
# 3     ['   فحص أداء المعدّات الكهربائية والميكانيكية...
# 4     ['   تدقيق المطالبات المالية والتأكد من اكتمال...
# ...                                                 ...
# 1465  ['   متابعة وتقييم عملية جمع وتحليل المعطيات و...
# 1466  ['   تدوين الملاحظات، التي يتم إملاؤها، بطريقة...
# 1467  ['   دراسة مواصفات وتركيبات الادوية والعقاقير ...
# 1468  ['   تسوية الرخام بواسطة أقراص الألماس الحديدي...
# 1469  ['   دراسة مواصفات وتركيبات الادوية والعقاقير ...
#
#                                               comp_name     comp_no comp_type  \
# 0                              شركة مقر العالم للسفريات    1-317262       خاص
# 1                          شركة عالم الكهرباء للمقاولات   4-1324428       خاص
# 2                                       شركه دار السلام    1-155294       خاص
# 3                               مؤسسة لمكو لغيار الزيوت   8-1925495       خاص
# 4                          مؤسسة فكرة اليمامة للمقاولات   1-2356639       خاص
# ...                                                 ...         ...       ...
# 1465                  مطعم الاوراق الخضر لتقديم الوجبات  15-1698448       خاص
# 1466         شركة ملتقى التجار لحاضنات و مسرعات الأعمال   9-2013930       خاص
# 1467                شركة تقنية الدواجن والألبان للتجارة   1-2415250       خاص
# 1468  مصنع عبدالرحمن بن محمد بن عبدالعزيز العبدالقاد...  15-1971895       خاص
# 1469                شركة تقنية الدواجن والألبان للتجارة   1-2415250       خاص
#
#          comp_size                                       eco_activity  \
# 0     متوسطة فئة أ                        أنشطة وكالات السياحة والسفر
# 1     متوسطة فئة ب  تركيب انظمة التبريد وتكييف الهواء وصيانتها واص...
# 2     متوسطة فئة أ               ترميمات المباني السكنية والغير سكنية
# 3      صغيرة فئة ب                                                NaN
# 4            كبيرة                   الإنشاءات العامة للمباني السكنية
# ...            ...                                                ...
# 1465   صغيرة فئة ب                                  المطاعم مع الخدمة
# 1466   صغيرة فئة ب                       أنشطة حاضنات ومسرعات الأعمال
# 1467   صغيرة فئة ب                                                NaN
# 1468   صغيرة فئة أ                                                NaN
# 1469   صغيرة فئة ب                                                NaN
#
#                                                  qualif           region  \
# 0        ['Language data', 'اللغة الانجليزية', 'محترف']           الرياض
# 1                                                   NaN  المنطقة الشرقية
# 2              ['Language data', 'الانجليزيه', 'محترف']           الرياض
# 3     ['Skill data', 'صيانة السيارات وتقييم الاعطال'...  المنطقة الشرقية
# 4     ['Skill data', 'تحمل ضغط العمل', 'محترف', 'Lan...           الرياض
# ...                                                 ...              ...
# 1465                                                NaN           الرياض
# 1466  ['Skill data', 'فن التواصل', 'محترف', 'Languag...      مكة المكرمة
# 1467  ['Professional certificate \\ License data', '...           الرياض
# 1468  ['Skill data', 'متقن للعمل وشغوف ويرغب بالتطور...  المنطقة الشرقية
# 1469  ['Professional certificate \\ License data', '...           الرياض
#
#               city                                           benefits  \
# 0     AR RIYADH...                               ['Salary', '5000.0']
# 1     AD DAMMAM...                               ['Salary', '5000.0']
# 2     ATH THUMA...                               ['Salary', '4000.0']
# 3      AL HUFUF...                               ['Salary', '5000.0']
# 4     AR RIYADH...                               ['Salary', '5000.0']
# ...            ...                                                ...
# 1465  AR RIYADH...                               ['Salary', '5500.0']
# 1466     JEDDAH...                               ['Salary', '4000.0']
# 1467  AR RIYADH...                               ['Salary', '7000.0']
# 1468  AL KHUBAR...  ['Salary', '4000.0', 'Benefits', 'اجازة سنوية ...
# 1469  AR RIYADH...                               ['Salary', '7000.0']
#
#        contract positions     job_post_id    exper gender
# 0     دوام كامل     0 / 1  20202026350419  0 Years   both
# 1     دوام كامل     0 / 3  20202026350389  0 Years   both
# 2     دوام كامل     0 / 2  20202026350347  2 Years   both
# 3     دوام كامل    0 / 10  20202026350219  0 Years      M
# 4     دوام كامل     0 / 1  20202026350043  0 Years   both
# ...         ...       ...             ...      ...    ...
# 1465  دوام كامل     0 / 1  20202026400353  0 Years   both
# 1466  دوام كامل     0 / 1  20202026399849  2 Years   both
# 1467  دوام كامل     0 / 1  20202026399061  0 Years   both
# 1468  دوام كامل     0 / 3  20202026398972  0 Years      M
# 1469  دوام كامل     0 / 1  20202026399061  0 Years   both
#
# [1470 rows x 18 columns]>

# %%
df.shape
# Out:
# (1470, 18)

# %%
df.describe()
# Out:
#         job_post_id
# count  1.470000e+03
# mean   2.020203e+13
# std    5.863941e+04
# min    2.020203e+13
# 25%    2.020203e+13
# 50%    2.020203e+13
# 75%    2.020203e+13
# max    2.020203e+13

# %%
df.columns
# Out:
# Index(['job_title', 'job_date', 'job_desc', 'job_tasks', 'comp_name',
#        'comp_no', 'comp_type', 'comp_size', 'eco_activity', 'qualif', 'region',
#        'city', 'benefits', 'contract', 'positions', 'job_post_id', 'exper',
#        'gender'],
#       dtype='object')

# %% [markdown]
# The process of profiling differs slightly for categorical and numerical variables due to their inherent differences.
#
# **The two main types of data are:**
# - Quantitative (numerical) data
# - Qualitative (categorical) data

# %% [markdown]
# ### Data Quality Checks
# Data quality checks involve the process of ensuring that the data is accurate, complete, consistent, relevant, and reliable.
#
#
# **Here are typical steps involved in checking data quality:**

# %% [markdown]
# #### 1. Reliability:
# Evaluate the data's source and collection process to determine its trustworthiness.

# %%
#data from Jadarat

# %% [markdown]
# #### 2. Timeliness:
# Ensure the data is up-to-date and reflective of the current situation or the period of interest for the analysis.

# %%
#Updated a year ago (2023)

# %% [markdown]
# #### 3. Consistency:
#
# Confirm that the data is consistent within the dataset and across multiple data sources. For example, the same data point should not have different values in different places.

# %% [markdown]
# #### 4. Relevance:
# Assess whether the data is appropriate and applicable for the intended analysis. Data that is not relevant can skew results and lead to incorrect conclusions.
#
# **Key considerations for relevance include:**
#
# > 1. Sample Appropriateness: Confirm that your data sample aligns with your analysis objectives. For instance, utilizing data from the Northern region will not yield accurate insights for the Western region of the Kingdom.
# >
# > 2. Variable Selection: Any column will not be relevant for our analysis, we can get rid of these using the drop() method. We will set the “axis” argument to 1 since we’re dealing with columns, and set the “inplace” argument to True to make the change permanent.

# %%
#comp_no,job_post_id

# %% [markdown]
# #### 5. Uniqueness:
# Check for and remove duplicate records to prevent skewed analysis results.

# %%
df.duplicated().sum().sum()
# Out:
# 1

# %%
# go to delete duplicates columns

# %% [markdown]
# #### 6. Completeness:
# Ensure that no critical data is missing. This might mean checking for null values or required fields that are empty.
#
# We will start by checking the dataset for missing or null values. For this, we can use the isna() method which returns a dataframe of boolean values indicating if a field is null or not. To group all missing values by column, we can include the sum() method.

# %%
#Display number missing values per column
df.isna().sum()
# Out:
# job_title         0
# job_date          0
# job_desc          0
# job_tasks         0
# comp_name         0
# comp_no           0
# comp_type         0
# comp_size        14
# eco_activity     90
# qualif          690
# region            0
# city              0
# benefits          0
# contract          0
# positions         0
# job_post_id       0
# exper             0
# gender            0
# dtype: int64

# %%
count = (df == '-').sum().sum()

print(count)
# Out:
# 0

# %%
count_ = (df == '/').sum().sum()

print(count_)
# Out:
# 0

# %%
# go to clean them

# %% [markdown]
# #### 7. Check Accuracy:
#
# Verify that the data is correct and precise. This could involve comparing data samples with known sources or using validation rules.
#
# **The process includes:**
# 1. Validating the appropriateness of data types for the dataset.
# 2. Identifying outliers  using established validation  rule

# %%
# check columns types 
df.dtypes
# Out:
# job_title       object
# job_date        object
# job_desc        object
# job_tasks       object
# comp_name       object
# comp_no         object
# comp_type       object
# comp_size       object
# eco_activity    object
# qualif          object
# region          object
# city            object
# benefits        object
# contract        object
# positions       object
# job_post_id      int64
# exper           object
# gender          object
# dtype: object

# %%
# go to clean them

# %%
# check outliers

# %%
df['Experience / Yare'].unique()
# Out:
# array([ 0,  2,  4, 10,  7, 12])

# %%
df['Salary / SAR'].unique()
# Out:
# array([ 5000.,  4000.,  4500.,  6000.,  8000., 10000.,  7200.,  7000.,
#         3000.,  9000., 12000.,  5500.,  8400.,  3200.,  4170.,  3640.,
#         5250.,  4400.,  4082.,  6150.,  6500., 15000., 16000.,  5700.,
#         4782.,  4375.,  4434., 13889.,  4444.,  4800.,  5625.,  9200.,
#         5600.,  8803.,  3500.,  5093.,  5800.,  5200.,  8500.,  3600.,
#         7500.,  4408., 27000.,  4083.,  4600.,  8496.,  6250.,  8333.,
#        32000., 12325.,  6583.,  5599.,  9500., 11000.,  4750.,  4320.,
#         4630.,  5066.,  4687.,  4625., 10250.,  5040.,  3198.,  4050.,
#         9600.,  4200., 35000., 13200.,  5271., 15532.,  4667.,  4300.,
#         4001.,  3300.,  5483.,  7757., 18000.,  6999.,  9900.,  4900.,
#        12400.,  9259., 14000.,  4100.,  5556.])

# %%
df['Salary / SAR'].max()
# Out:
# 35000.0

# %%
df['Salary / SAR'].min()
# Out:
# 3000.0

# %%
df['Number of vacancies'].unique()
# Out:
# array([ 1,  3,  2, 10,  4,  5,  9, 50,  6, 46,  8, 25, 20, 15,  7, 30])

# %%
df.columns
# Out:
# Index(['Job Title', 'Job Date', 'Job Description', 'Job Tasks', 'Company Name',
#        'Company Type', 'Company Size', 'Economic Activity', 'Qualification',
#        'Region', 'City', 'Benefits', 'Contract', 'Number of vacancies',
#        'Experience / Yare', 'Gender', 'Salary / SAR'],
#       dtype='object')

# %%
sns.histplot(data=df, 
            x="Experience / Yare",
             y = "Salary / SAR",
            )
# Out:
# <Axes: xlabel='Experience / Yare', ylabel='Salary / SAR'>

# %%
plt.figure(figsize=(15,8))
t10 = df.head(10)
sns.boxplot(
    df,
    x="Experience / Yare",
             y = "Salary / SAR",
    #z="Company Size"
)
# Out:
# <Axes: xlabel='Experience / Yare', ylabel='Salary / SAR'>

# %% [markdown]
# **What is an Outlier?**
# Outlier is an row/observation that appears far away and diverges from an overall pattern in a sample.
#
# **What are the types of Outliers?**
# 1. Univariate: These outliers can be found when we look at distribution of a single variable
# 2. Multivariate: are outliers in an n-dimensional space. In order to find them, you have to look at distributions in multi-dimensions. example (hight=100, weight=100) for a person
#
# **What causes Outliers?**
# Whenever we come across outliers, the ideal way to tackle them is to find out the reason of having these outliers. The method to deal with them would then depend on the reason of their occurrence.
#
# Let’s understand various types of outliers:
#
# 1. Data Entry Errors:- Human errors such as errors caused during data collection, recording, or entry can cause outliers in data.
# 2. Measurement Error: It is the most common source of outliers. This is caused when the measurement instrument used turns out to be faulty.
# 3. Data Processing Error: Whenever we perform data mining, we extract data from multiple sources. It is possible that some manipulation or extraction errors may lead to outliers in the dataset.
# 4. Sampling error: For instance, we have to measure the height of athletes. By mistake, we include a few basketball players in the sample. This inclusion is likely to cause outliers in the dataset.
# 5. Natural Outlier: When an outlier is not artificial (due to error), it is a natural outlier. For instance: In my last assignment with one of the renowned insurance company, I noticed that the performance of top 50 financial advisors was far higher than rest of the population. Surprisingly, it was not due to any error. Hence, whenever we perform any data mining activity with advisors, we used to treat this segment separately.
#
#
# **What is the impact of Outliers on a dataset?**
#
#
# ![image.png](https://www.analyticsvidhya.com/wp-content/uploads/2015/02/Outlier_31.png)
#
#
#
# **How to detect Outliers?**
#
# 1. Most commonly used method to detect outliers is visualization (Univariate Graphical Analysis).
#
# We use 3 common visualization methods:
# >- Box-plot: A box plot is a method for graphically depicting groups of numerical data through their quartiles. The box extends from the Q1 to Q3 quartile values of the data, with a line at the median (Q2). The whiskers extend from the edges of the box to show the range of the data. Outlier points are those past the end of the whiskers. Box plots show robust measures of location and spread as well as providing information about symmetry and outliers.
# >
# >
# >![image.png](https://miro.medium.com/v2/resize:fit:698/format:webp/1*VK5iHA2AB28HSZwWwUbNYg.png)
# >
# >
# >- Histogram
# >- Scatter Plot: A scatter plot is a mathematical diagram using Cartesian coordinates to display values for two variables for a set of data. The data are displayed as a collection of points, each having the value of one variable determining the position on the horizontal axis and the value of the other variable determining the position on the vertical axis. The points that are far from the population can be termed as an outlier.
# >
# >
# >![image.png](https://miro.medium.com/v2/resize:fit:4800/format:webp/1*Ov6aH-8yIwNoUxtMFwgx4g.png)
# >
# >
#
# 2. Using statistical method (Univariate Non-Graphical analysis):
# >- Any value, which is beyond the range of -1.5 x IQR to 1.5 x IQR
#
# ![image.png](https://www.whatissixsigma.net/wp-content/uploads/2015/07/Box-Plot-Diagram-to-identify-Outliers-figure-1.png)
#
# >- Use capping methods. Any value which out of range of 5th and 95th percentile can be considered as outlier
# >- Data points, three or more standard deviation away from mean are considered outlier: The Z-score is the signed number of standard deviations by which the value of an observation or data point is above the mean value of what is being observed or measured. While calculating the Z-score we re-scale and center the data and look for data points that are too far from zero. These data points which are way too far from zero will be treated as the outliers. In most of the cases, a threshold of 3 or -3 is used i.e if the Z-score value is greater than or less than 3 or -3 respectively, that data point will be identified as outliers.
# > - Outlier detection is merely a special case of the examination of data for influential data points and it also depends on the business understanding

# %%
# go to univariate graphical analysis
# go to lesson : data visualisation 1 - chart type section
# then go to univariate graphical analysis
# detect outliers using graphs varbaly

# %%
# go to lesson: statistics 1 then statistics 3
# then go to univariate Non graphical analysis
# detect outliers using numerical statistics

# %%
# go to delete ouliers

# %% [markdown]
# ## 2. Data Cleaning:
#
# Preliminary findings from data profiling can lead to cleaning the data by:
# - Handling missing values
# - Correcting errors.
# - Dealing with outliers.
#
# -------------------

# %% [markdown]
# ### Handling missing values:

# %% [markdown]
# **Why my data has missing values?**
# They may occur at two stages:
# 1. Data Extraction: It is possible that there are problems with extraction process. Errors at data extraction stage are typically easy to find and can be corrected easily as well.
# 2. Data collection: These errors occur at time of data collection and are harder to correct.
#
# **Why do we need to handle the missing data?**
# To avoid:
# - Bias the conclusions.
# - Leading the business to make wrong decisions.
#
# **Which are the methods to treat missing values ?**
# 1. Deletion: we delete rows where any of the variable is missing. Simplicity is one of the major advantage of this method, but this method reduces the power of model because it reduces the sample size.
#
# 2. Imputation: is a method to fill in the missing values with estimated ones. This imputation is one of the most frequently used methods.
#
#     2.1. Mean/ Mode/ Median Imputation: It consists of replacing the missing data for a given attribute by the mean or median (quantitative attribute) or mode (qualitative attribute) of all known values of that variable.
#     > It can be of two types:
#     > - Generalized Imputation: In this case, we calculate the mean or median for all non missing values of that variable then replace missing value with mean or median.
#     > - Similar case Imputation: In this case, we calculate average for each group individually of non missing values then replace the missing value based on the group.
#
#     2.2. Constant Value
#
#     2.3. Forward Filling
#
#     2.4. Backward Filling
#
# 6. Prediction Model:  Prediction model is one of the sophisticated method for handling missing data. Here, we create a predictive model to estimate values that will substitute the missing data.  In this case, we divide our data set into two sets: One set with no missing values for the variable and another one with missing values. First data set become training data set of the model while second data set with missing values is test data set and variable with missing values is treated as target variable. Next, we create a model to predict target variable based on other attributes of the training data set and populate missing values of test data set.
#
# > There are 2 drawbacks for this approach:
# > - The model estimated values are usually more well-behaved than the true values
# > - If there are no relationships with attributes in the data set and the attribute with missing values, then the model will not be precise for estimating missing values.
#
# 9. KNN Imputation: In this method of imputation, the missing values of an attribute are imputed using the given number of attributes that are most similar to the attribute whose values are missing. The similarity of two attributes is determined using a distance function. It is also known to have certain advantage & disadvantages.
#
#    > **Advantages:**
#    > - k-nearest neighbour can predict both qualitative & quantitative attributes
#    > - Creation of predictive model for each attribute with missing data is not required
#    > - Attributes with multiple missing values can be easily treated
#    > - Correlation structure of the data is taken into consideration
#
#    > **Disadvantage:**
#    > - KNN algorithm is very time-consuming in analyzing large database. It searches through all the dataset looking for the most similar instances.
#    > - Choice of k-value is very critical. Higher value of k would include attributes which are significantly different from what we need whereas lower value of k implies missing out of significant attributes.
#
# --------------------

# %%
df.isna().sum()
# Out:
# job_title         0
# job_date          0
# job_desc          0
# job_tasks         0
# comp_name         0
# comp_no           0
# comp_type         0
# comp_size        14
# eco_activity     90
# qualif          690
# region            0
# city              0
# benefits          0
# contract          0
# positions         0
# job_post_id       0
# exper             0
# gender            0
# dtype: int64

# %%
df[df['qualif'].isna()]
# Out:
#                       job_title    job_date  \
# 1                          بائع  27/05/1444
# 14                  مصمم جرافيك  26/05/1444
# 15                  مدخل بيانات  26/05/1444
# 16                   مطور برامج  26/05/1444
# 17            أخصائي إدارة اداء  26/05/1444
# ...                         ...         ...
# 1454  أخصائي عمليات موارد بشرية  25/06/1444
# 1455            فني تصميم داخلي  24/06/1444
# 1460                    كيميائي  23/06/1444
# 1464                       بائع  21/06/1444
# 1465        مهندس تقنية معلومات  19/06/1444
#
#                                                job_desc  \
# 1     ['بيع مجموعة من السلع والخدمات للعملاء، وتوفير...
# 14    ['لديه الخبرة   في اخراج العروض التقديمية الرس...
# 15          ['التمكن من استخدام برامج مايكروسفت أوفيس']
# 16    [' تحليل  وادارة تطبيقات باستخدام الأدوات البر...
# 17    [' فهم مبادئ الإدارة الإستراتيجية وقياس الأداء...
# ...                                                 ...
# 1454  ['تنفيذ الإجراءات والأنظمة والنماذج الخاصة بمر...
# 1455  ['تصميم أنظمة الألوان وطرز الأثاث، والمواد الم...
# 1460  ['دراسة خصائص المواد الكميائية للصناعات الكيمي...
# 1464  ['بيع مجموعة من السلع والخدمات للعملاء، وتوفير...
# 1465  ['دراسة احتياجات العميل من الأجهزة الحاسوبية و...
#
#                                               job_tasks  \
# 1     ['   بيع مجموعة من السلع والخدمات للعملاء.', '...
# 14    ['لديه الخبرة   في اخراج العروض التقديمية الرس...
# 15          ['التمكن من استخدام برامج مايكروسفت أوفيس']
# 16    ['   تحليل  وادارة تطبيقات باستخدام الأدوات ال...
# 17    [' فهم مبادئ الإدارة الإستراتيجية وقياس الأداء...
# ...                                                 ...
# 1454  ['   تنفيذ الإجراءات والأنظمة والنماذج الخاصة ...
# 1455  ['   وضع التصاميم للمشروعات الداخلية، وإدارة ف...
# 1460  ['   إعداد برامج تشغيل الأجهزة والمعدات المخبر...
# 1464  ['   بيع مجموعة من السلع والخدمات للعملاء.', '...
# 1465  ['   متابعة وتقييم عملية جمع وتحليل المعطيات و...
#
#                                               comp_name     comp_no comp_type  \
# 1                          شركة عالم الكهرباء للمقاولات   4-1324428       خاص
# 14                      مكتب مدارات للاستشارات الهندسية   3-1971776       خاص
# 15                      مكتب مدارات للاستشارات الهندسية   3-1971776       خاص
# 16                      مكتب مدارات للاستشارات الهندسية   3-1971776       خاص
# 17                      مكتب مدارات للاستشارات الهندسية   3-1971776       خاص
# ...                                                 ...         ...       ...
# 1454                                  شركـة ذوق للتجارة   1-1526321       خاص
# 1455          شركة نمو للبحوث والدراسات (شركة شخص واحد)   1-2166711       خاص
# 1460                       شركة نواف صالح البطي للتجارة   1-2604723       خاص
# 1464  شركة النجمة الذهبية للتبريد والتكييف شركة شخص ...   8-1977608       خاص
# 1465                  مطعم الاوراق الخضر لتقديم الوجبات  15-1698448       خاص
#
#          comp_size                                       eco_activity qualif  \
# 1     متوسطة فئة ب  تركيب انظمة التبريد وتكييف الهواء وصيانتها واص...    NaN
# 14    متوسطة فئة ب                           إدارة المشاريع الانشائية    NaN
# 15    متوسطة فئة ب                           إدارة المشاريع الانشائية    NaN
# 16    متوسطة فئة ب                           إدارة المشاريع الانشائية    NaN
# 17    متوسطة فئة ب                           إدارة المشاريع الانشائية    NaN
# ...            ...                                                ...    ...
# 1454   صغيرة فئة ب         البيع بالتجزئة للوكلاء بالعمولة بدون محلات    NaN
# 1455   صغيرة فئة أ                  مراكز البحوث والدراسات الاجتماعية    NaN
# 1460   صغيرة فئة ب  تجارة الجملة والتجزئه في أنواع أخرى من المركبا...    NaN
# 1464   صغيرة فئة ب  تركيب انظمة التبريد وتكييف الهواء وصيانتها واص...    NaN
# 1465   صغيرة فئة ب                                  المطاعم مع الخدمة    NaN
#
#                region          city  \
# 1     المنطقة الشرقية  AD DAMMAM...
# 14               حائل       HAIL...
# 15               حائل       HAIL...
# 16               حائل       HAIL...
# 17               حائل       HAIL...
# ...               ...           ...
# 1454           الرياض  AR RIYADH...
# 1455           الرياض  AR RIYADH...
# 1460           الرياض  AR RIYADH...
# 1464  المنطقة الشرقية   AL HUFUF...
# 1465           الرياض  AR RIYADH...
#
#                                        benefits   contract positions  \
# 1                          ['Salary', '5000.0']  دوام كامل     0 / 3
# 14                         ['Salary', '7000.0']  دوام كامل     0 / 1
# 15                         ['Salary', '3000.0']  دوام كامل     0 / 2
# 16                         ['Salary', '9000.0']  دوام كامل     0 / 1
# 17                        ['Salary', '12000.0']  دوام كامل     0 / 1
# ...                                         ...        ...       ...
# 1454                       ['Salary', '5556.0']  دوام كامل     0 / 1
# 1455  ['Salary', '5000.0', 'Benefits', 'عموله']  دوام كامل     0 / 1
# 1460                       ['Salary', '5000.0']  دوام كامل     0 / 1
# 1464                       ['Salary', '4000.0']  دوام كامل     0 / 1
# 1465                       ['Salary', '5500.0']  دوام كامل     0 / 1
#
#          job_post_id     exper gender
# 1     20202026350389   0 Years   both
# 14    20202026349504   4 Years      M
# 15    20202026349475   2 Years      M
# 16    20202026349439   4 Years      M
# 17    20202026349417  10 Years      M
# ...              ...       ...    ...
# 1454  20202026403956   0 Years      F
# 1455  20202026403328   2 Years   both
# 1460  20202026402275   0 Years      F
# 1464  20202026401107   2 Years      F
# 1465  20202026400353   0 Years   both
#
# [690 rows x 18 columns]

# %%
#By referring to the Jadarat website, it is clear that entering Qualification is not mandatory.
df['qualif'] = df['qualif'].fillna(value = 'No requarment')

# %%
df[df['qualif'].isna()]
# Out:
# Empty DataFrame
# Columns: [job_title, job_date, job_desc, job_tasks, comp_name, comp_no, comp_type, comp_size, eco_activity, qualif, region, city, benefits, contract, positions, job_post_id, exper, gender]
# Index: []

# %%
df[df['comp_size'].isna()]
# Out:
#                 job_title    job_date  \
# 1296           مدير إداري  25/06/1444
# 1393    موظف صندوق محاسبة  01/07/1444
# 1399    موظف صندوق محاسبة  29/06/1444
# 1401           وسيط عقاري  29/06/1444
# 1409                محامي  29/06/1444
# 1411        أخصائي قانوني  29/06/1444
# 1421            مدير مالي  29/06/1444
# 1426             مصفف شعر  29/06/1444
# 1432    موظف صندوق محاسبة  27/06/1444
# 1436    أخصائي علاج طبيعي  26/06/1444
# 1438                 بائع  26/06/1444
# 1444  مشرف مدخلي البيانات  26/06/1444
# 1451        فني مختبر طبي  25/06/1444
# 1456                محامي  24/06/1444
#
#                                                job_desc  \
# 1296  ['المشاركة في تطوير الأهداف الرئيسية للشؤون ال...
# 1393  ['عد المبالغ المالية المتوافرة في آلة تسجيل ال...
# 1399  ['عد المبالغ المالية المتوافرة في آلة تسجيل ال...
# 1401  ['مساعدة البائعين وتقديم اقتراحات بأفضل طريقة ...
# 1409  ['دراسة القضية وتجهيز ملفها وجمع البينات الخطي...
# 1411  ['مساعدة العملاء والمنشآت في مختلف المسائل الق...
# 1421  ['المشاركة في تطوير الأهداف الرئيسية للإدارة ا...
# 1426  ['تقديم المشورة للعميل وتسريح الشعر وتصفيفه وت...
# 1432  ['عد المبالغ المالية المتوافرة في آلة تسجيل ال...
# 1436  ['دراسة وتحليل الحالة المرضية ووضع خطة وبرنامج...
# 1438  ['بيع مجموعة من السلع والخدمات للعملاء، وتوفير...
# 1444  ['الإشراف على مدخلي البيانات والتأكد من صحة ال...
# 1451  ['تفقد وتشغيل وخدمة معدات المختبر،أخذ عينات ال...
# 1456  ['دراسة القضية وتجهيز ملفها وجمع البينات الخطي...
#
#                                               job_tasks  \
# 1296  ['   المشاركة في تطوير الأهداف الرئيسية للشؤون...
# 1393  ['   عدّ المبالغ المالية وتسجيلها في آلة تسجيل...
# 1399  ['   عدّ المبالغ المالية وتسجيلها في آلة تسجيل...
# 1401  ['   تقييم رغبات العملاء والميزانيات المحددة و...
# 1409  ['   استقبال القضية وتحديد نوعها وتحليل عناصره...
# 1411  ['   تأهيل الطلبات وتقييم الخيارات القانونية، ...
# 1421  ['   المشاركة في تطوير الأهداف الرئيسية للإدار...
# 1426  ['   استقبال العميل وإجلاسه على كرسي القص  ووض...
# 1432  ['   عدّ المبالغ المالية وتسجيلها في آلة تسجيل...
# 1436  ['   دراسة وتحليل برنامج المعالجة الطبيعية الم...
# 1438  ['   بيع مجموعة من السلع والخدمات للعملاء.', '...
# 1444  ['   تدقيق البيانات بعد إدخالها، والتأكد من صح...
# 1451  ['   تفقد وتشغيل وخدمة معدات حفظ وفحص العينات ...
# 1456  ['   استقبال القضية وتحديد نوعها وتحليل عناصره...
#
#                                               comp_name     comp_no comp_type  \
# 1296            مكتب تصميم المشاريع للاستشارات الهندسية   4-1990473       خاص
# 1393                            مغاسل نسيم الفل للملابس  15-1963098       خاص
# 1399                            مغاسل نسيم الفل للملابس  15-1963098       خاص
# 1401                                مؤسسة فانس العقارية   1-2268591       خاص
# 1409  شركة الخبراء المتحدون للمحاماة والاستشارات الق...   1-2334348       خاص
# 1411  شركة الخبراء المتحدون للمحاماة والاستشارات الق...   1-2334348       خاص
# 1421                شركة إرفاء المحدودة (شركة شخص واحد)  17-1989300       خاص
# 1426                   صالون تشرين ثاني للتزيين النسائي   1-2593881       خاص
# 1432                  مؤسسة التذوق الحلو لتقديم الوجبات   1-2559144       خاص
# 1436             مجمع ارجوان سامي بن نائف العتيبي الطبي   2-1949575       خاص
# 1438                مؤسسة ريان سعد عواد الدهام للحلويات   4-1971557       خاص
# 1444                          خالد عوض الجوهي للمقاولات   1-2073853       خاص
# 1451                         مجمع ابتسامة العائلة الطبي   1-2599562       خاص
# 1456        شركة فيصل عبد الله الفوزان وشركاؤه للمحاماة   1-2664602       خاص
#
#      comp_size                          eco_activity  \
# 1296       NaN                                   NaN
# 1393       NaN                                   NaN
# 1399       NaN                                   NaN
# 1401       NaN                                   NaN
# 1409       NaN                                   NaN
# 1411       NaN                                   NaN
# 1421       NaN                                   NaN
# 1426       NaN                                   NaN
# 1432       NaN                                   NaN
# 1436       NaN                                   NaN
# 1438       NaN                                   NaN
# 1444       NaN                                   NaN
# 1451       NaN                                   NaN
# 1456       NaN  أنشطة المحاماة والاستشارات القانونية
#
#                                                  qualif           region  \
# 1296                                      No requarment  المنطقة الشرقية
# 1393                                      No requarment  المنطقة الشرقية
# 1399                                      No requarment           الرياض
# 1401  ['Skill data', 'عقاري', 'مبتدئ', 'Language dat...           الرياض
# 1409  ['Professional certificate \\ License data', '...           الرياض
# 1411  ['Skill data', 'إدارة وتنظيم المستندات والوثائ...           الرياض
# 1421                                      No requarment             حائل
# 1426                ['Skill data', 'صف الشعر', 'متوسط']           الرياض
# 1432                                      No requarment           الرياض
# 1436                                      No requarment           الرياض
# 1438  ['Language data', 'العربية', 'محترف', 'الانجلي...           الرياض
# 1444  ['Skill data', 'اتقان الحاسب ', 'متوسط', 'Lang...           الرياض
# 1451  ['Professional certificate \\ License data', '...           الرياض
# 1456  ['Skill data', 'التعامل مع برامج الأوفيس', 'مح...           الرياض
#
#               city               benefits   contract positions  \
# 1296  AD DAMMAM...  ['Salary', '12400.0']  دوام كامل     0 / 1
# 1393  AL KHUBAR...   ['Salary', '4000.0']  دوام كامل     0 / 3
# 1399  AL KHUBAR...   ['Salary', '4000.0']  دوام كامل     0 / 2
# 1401      RUMAH...   ['Salary', '4000.0']  دوام كامل     0 / 1
# 1409  AR RIYADH...   ['Salary', '5000.0']  دوام كامل     0 / 2
# 1411  AR RIYADH...   ['Salary', '4000.0']  دوام كامل     0 / 2
# 1421  ABA AL HI...  ['Salary', '14000.0']  دوام كامل     0 / 1
# 1426  AR RIYADH...   ['Salary', '4000.0']  دوام كامل     0 / 2
# 1432   AL BIYAD...   ['Salary', '4000.0']  دوام كامل     0 / 2
# 1436   AL KHARJ...   ['Salary', '4000.0']  دوام كامل     0 / 1
# 1438  AR RIYADH...   ['Salary', '4500.0']  دوام كامل     0 / 2
# 1444  HAFIRAT N...   ['Salary', '4500.0']  دوام كامل     0 / 5
# 1451  AR RIYADH...   ['Salary', '5000.0']  دوام كامل     0 / 2
# 1456  AR RIYADH...   ['Salary', '4000.0']  دوام كامل     0 / 1
#
#          job_post_id    exper gender
# 1296  20202026404052  7 Years      M
# 1393  20202026407308  0 Years   both
# 1399  20202026407112  0 Years   both
# 1401  20202026407053  0 Years      F
# 1409  20202026406912  2 Years   both
# 1411  20202026406840  0 Years   both
# 1421  20202026406695  7 Years   both
# 1426  20202026406598  4 Years      F
# 1432  20202026406120  0 Years      M
# 1436  20202026405893  0 Years      F
# 1438  20202026405668  2 Years      M
# 1444  20202026405354  0 Years   both
# 1451  20202026404173  0 Years   both
# 1456  20202026403115  0 Years   both

# %%
#Referring back to the specifications of the records in which the
#company size is empty, it was found that they are small institutions,
#so the value of the empty space was replaced with “مؤسسات صغيرة”
df['comp_size'] = df['comp_size'].fillna(value = 'مؤسسات صغيرة')

# %%
df
# Out:
#                       job_title    job_date  \
# 0                         محاسب  27/05/1444
# 1                          بائع  27/05/1444
# 2     أخصائي عمليات موارد بشرية  27/05/1444
# 3               ميكانيكي سيارات  27/05/1444
# 4                         محاسب  27/05/1444
# ...                         ...         ...
# 1465        مهندس تقنية معلومات  19/06/1444
# 1466                     سكرتير  19/06/1444
# 1467                      صيدلي  18/06/1444
# 1468        مشغل آلة تشطيب رخام  18/06/1444
# 1469                      صيدلي  18/06/1444
#
#                                                job_desc  \
# 0     ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
# 1     ['بيع مجموعة من السلع والخدمات للعملاء، وتوفير...
# 2     ['تنفيذ الإجراءات والأنظمة والنماذج الخاصة بمر...
# 3     ['تشخيص أعطال السيارات وإصلاحها وتنفيذ برامج ا...
# 4     ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
# ...                                                 ...
# 1465  ['دراسة احتياجات العميل من الأجهزة الحاسوبية و...
# 1466  ['دعم المدير أو الإدارة من خلال كتابة الوثائق ...
# 1467  ['دراسة التركيبات الدوائية للعقاقير والعلاجات ...
# 1468  ['تشغيل آلة تشطيب الرخام وابعادء الأجزاء المتف...
# 1469  ['دراسة التركيبات الدوائية للعقاقير والعلاجات ...
#
#                                               job_tasks  \
# 0     ['   تدقيق المطالبات المالية والتأكد من اكتمال...
# 1     ['   بيع مجموعة من السلع والخدمات للعملاء.', '...
# 2     ['   تنفيذ الإجراءات والأنظمة والنماذج الخاصة ...
# 3     ['   فحص أداء المعدّات الكهربائية والميكانيكية...
# 4     ['   تدقيق المطالبات المالية والتأكد من اكتمال...
# ...                                                 ...
# 1465  ['   متابعة وتقييم عملية جمع وتحليل المعطيات و...
# 1466  ['   تدوين الملاحظات، التي يتم إملاؤها، بطريقة...
# 1467  ['   دراسة مواصفات وتركيبات الادوية والعقاقير ...
# 1468  ['   تسوية الرخام بواسطة أقراص الألماس الحديدي...
# 1469  ['   دراسة مواصفات وتركيبات الادوية والعقاقير ...
#
#                                               comp_name     comp_no comp_type  \
# 0                              شركة مقر العالم للسفريات    1-317262       خاص
# 1                          شركة عالم الكهرباء للمقاولات   4-1324428       خاص
# 2                                       شركه دار السلام    1-155294       خاص
# 3                               مؤسسة لمكو لغيار الزيوت   8-1925495       خاص
# 4                          مؤسسة فكرة اليمامة للمقاولات   1-2356639       خاص
# ...                                                 ...         ...       ...
# 1465                  مطعم الاوراق الخضر لتقديم الوجبات  15-1698448       خاص
# 1466         شركة ملتقى التجار لحاضنات و مسرعات الأعمال   9-2013930       خاص
# 1467                شركة تقنية الدواجن والألبان للتجارة   1-2415250       خاص
# 1468  مصنع عبدالرحمن بن محمد بن عبدالعزيز العبدالقاد...  15-1971895       خاص
# 1469                شركة تقنية الدواجن والألبان للتجارة   1-2415250       خاص
#
#          comp_size                                       eco_activity  \
# 0     متوسطة فئة أ                        أنشطة وكالات السياحة والسفر
# 1     متوسطة فئة ب  تركيب انظمة التبريد وتكييف الهواء وصيانتها واص...
# 2     متوسطة فئة أ               ترميمات المباني السكنية والغير سكنية
# 3      صغيرة فئة ب                                                NaN
# 4            كبيرة                   الإنشاءات العامة للمباني السكنية
# ...            ...                                                ...
# 1465   صغيرة فئة ب                                  المطاعم مع الخدمة
# 1466   صغيرة فئة ب                       أنشطة حاضنات ومسرعات الأعمال
# 1467   صغيرة فئة ب                                                NaN
# 1468   صغيرة فئة أ                                                NaN
# 1469   صغيرة فئة ب                                                NaN
#
#                                                  qualif           region  \
# 0        ['Language data', 'اللغة الانجليزية', 'محترف']           الرياض
# 1                                         No requarment  المنطقة الشرقية
# 2              ['Language data', 'الانجليزيه', 'محترف']           الرياض
# 3     ['Skill data', 'صيانة السيارات وتقييم الاعطال'...  المنطقة الشرقية
# 4     ['Skill data', 'تحمل ضغط العمل', 'محترف', 'Lan...           الرياض
# ...                                                 ...              ...
# 1465                                      No requarment           الرياض
# 1466  ['Skill data', 'فن التواصل', 'محترف', 'Languag...      مكة المكرمة
# 1467  ['Professional certificate \\ License data', '...           الرياض
# 1468  ['Skill data', 'متقن للعمل وشغوف ويرغب بالتطور...  المنطقة الشرقية
# 1469  ['Professional certificate \\ License data', '...           الرياض
#
#               city                                           benefits  \
# 0     AR RIYADH...                               ['Salary', '5000.0']
# 1     AD DAMMAM...                               ['Salary', '5000.0']
# 2     ATH THUMA...                               ['Salary', '4000.0']
# 3      AL HUFUF...                               ['Salary', '5000.0']
# 4     AR RIYADH...                               ['Salary', '5000.0']
# ...            ...                                                ...
# 1465  AR RIYADH...                               ['Salary', '5500.0']
# 1466     JEDDAH...                               ['Salary', '4000.0']
# 1467  AR RIYADH...                               ['Salary', '7000.0']
# 1468  AL KHUBAR...  ['Salary', '4000.0', 'Benefits', 'اجازة سنوية ...
# 1469  AR RIYADH...                               ['Salary', '7000.0']
#
#        contract positions     job_post_id    exper gender
# 0     دوام كامل     0 / 1  20202026350419  0 Years   both
# 1     دوام كامل     0 / 3  20202026350389  0 Years   both
# 2     دوام كامل     0 / 2  20202026350347  2 Years   both
# 3     دوام كامل    0 / 10  20202026350219  0 Years      M
# 4     دوام كامل     0 / 1  20202026350043  0 Years   both
# ...         ...       ...             ...      ...    ...
# 1465  دوام كامل     0 / 1  20202026400353  0 Years   both
# 1466  دوام كامل     0 / 1  20202026399849  2 Years   both
# 1467  دوام كامل     0 / 1  20202026399061  0 Years   both
# 1468  دوام كامل     0 / 3  20202026398972  0 Years      M
# 1469  دوام كامل     0 / 1  20202026399061  0 Years   both
#
# [1470 rows x 18 columns]

# %%
df[df['comp_size'].isna()]
# Out:
# Empty DataFrame
# Columns: [job_title, job_date, job_desc, job_tasks, comp_name, comp_no, comp_type, comp_size, eco_activity, qualif, region, city, benefits, contract, positions, job_post_id, exper, gender]
# Index: []

# %%
fff = df[df['eco_activity'].isna()]

# %%
df['eco_activity'].unique()
# Out:
# array(['أنشطة وكالات السياحة والسفر',
#        'تركيب انظمة التبريد وتكييف الهواء وصيانتها واصلاحها',
#        'ترميمات المباني السكنية والغير سكنية', nan,
#        'الإنشاءات العامة للمباني السكنية',
#        'تشغيل المقاصف والكفتيريات على أساس إمتياز محدد ، يشمل ( المقاصف والكفتيريات في المصانع والمكاتب والمستشفيات والمدارس .. الخ )',
#        'إعادة تأهيل وهيكلة العمليات الإدارية والمالية والتشغيلية للمنشآت',
#        'البيع بالجملة للملابس الرياضية',
#        'تقديم خدمات تسويقية نيابةً عن الغير', 'إدارة المشاريع الانشائية',
#        'تركيب وصيانة أجهزة ومعدات الإنذار من الحريق',
#        'البيع بالجملة للمواد الكيميائية',
#        'أنشطة الاستشارات الهندسية والمعمارية',
#        'خدمات جمع النفايات البلدية',
#        'البيع بالتجزئة لمعدات محطات الوقود وقطع غيارها وتشمل (مضخات الوقود)',
#        'إنشاء وإقامة محطات وأبراج الاتصالات السلكية واللاسلكية والرادار',
#        'أنشطة المكاتب الرئيسة',
#        'أنشطة الخدمات الإدارية المتكاملة للمكاتب',
#        'مراكز ضيافة الأطفال الأهلية',
#        'خلط وتعبئة العطور والزيوت والنباتات',
#        'انتاج الغازات الأولية ، يشمل ( الاوكسجين والهيدروجين .. الخ )',
#        'إصلاح وصيانة المحطات والشبكات والخطوط الرئيسية لتوزيع المياه',
#        'الصالونات الرجالية', 'مجمعات تجارية استهلاكية',
#        'البيع بالتجزئة للمولدات الكهربائية ولوازمها',
#        'صناعة الخبز ومنتجاته بواسطة المخابز الآلية',
#        'غسل وكي والتنظيف الجاف لشتى أنواع الملابس بما فيها الفراء والمنسوجات وتشمل جمع وتوزيع الغسيل',
#        'بيع المشروبات بالتجزئة في المتاجر المتخصصة',
#        'رعاية وصيانة المنتزهات والحدائق لأغراض الإسكان العام',
#        'الخدمات الطبية بالمصحات المتخصصة ومراكز إعادة التأهيل والصحة الوقائية',
#        'أعمال وتركيب الديكورات المختلفة',
#        'أنشطة تصميم الديكورات الداخلية',
#        'بيع الأغذية والمشروبات بالتجزئة في الأكشاك والأسواق',
#        'البيع بالتجزئة للزهور والورود',
#        'إنشاء الطرق والشوارع والارصفة ومستلزمات الطرق',
#        'البيع بالجملة لمنتجات المخابز', 'الخدمات اللوجستية',
#        'البيع بالتجزئة للفواكه والخضروات الطازجة والمحفوظة',
#        'أنشطة إدارة العقارات مقابل عمولة',
#        'الحراسة الأمنية المدنية الخاصة', 'مراكز الطب البديل والتكميلي',
#        'المطاعم مع الخدمة', 'التعليم الابتدائي للطلاب بمنهج وطني',
#        'التعليم الابتدائي المختلط، يشمل مدارس الجاليات',
#        'محلات تقديم وجبات الفول و الحمص و الكبدة والبليلة والبازلاء و المطبق وما شابهها',
#        'إدارة وتأجير المخازن ذاتية التخزين',
#        'صناعة حديد الزهر ما في ذلك مسبوكات حديد الصلب والزهر',
#        'البيع بالجملة لقطع غيار معدات وآلات البناء',
#        'محلات الوجبات السريعة ( تشمل محلات البيتزاء )',
#        'تركيب وصيانة المصاعد',
#        'صناعة منتجات أولية من الحديد على شكل كتل من الركائز والمخلفات بعد إعادة صهرها',
#        'إنشاء المحطات والخطوط الرئيسية لتوزيع المياه',
#        'البيع بالتجزئة للساعات بأنواعها',
#        'الانشاءات العامة للمباني غير السكنية (مثل المدارس والمستشفيات والفنادق ....الخ)',
#        'التعليم في مرحلة ما قبل المدرسة - رياض الأطفال بمنهج وطني',
#        'بيع وتركيب معدات الفنادق والمطاعم والمطابخ والمغاسل الاتوماتيكية بالتجزئة',
#        'أنشطة اخرى خاصة بالنقل البري للبضائع',
#        'الأنشطة الخيرية ، يشمل: جمع التبرعات أو أنشطة الدعم الأخرى التي تدخل في نطاق العمل الاجتماعي',
#        'صناعة المطابخ من الخشب والألمنيوم الخ',
#        'البوفيهات ( الكافيتريات )', 'البيع بالجملة للخضراوات',
#        'البيع بالجملة للزهور', 'التركيبات الكهربائية الأخرى',
#        'أنشطة أخرى لسبك المعادن غير الحديدية (منتجات تامة ونصف تامة الصنع )',
#        'النقل البري للبضائع', 'تشغيل استوديو صوتي ومرئي',
#        'أنشطة المحاماة والاستشارات القانونية',
#        'انتاج زيوت التشحيم للمعدات والمحركات',
#        'الصالات والمراكز الرياضية النسائية', 'صب القواعد والاساسات',
#        'تركيب وتمديد شبكات الكمبيوتر والاتصالات',
#        'مستودع مستحضرات صيدلانية وعشبية', 'تقديم موارد بشرية أخرى',
#        'أنشطة تنظيف الطرق', 'البيع بالجملة للحوم والدواجن المجمدة',
#        'وكلاء البيع في الأغذية والمشروبات',
#        'مؤسسات الرفاه الاجتماعي (تحديد وتوزيع المساعدات الاجتماعية، الرعاية النهارية لذوي الاحتياجات الخاصة تبني الأطفال، الاستشارات للأسر والأفراد)',
#        'تنظيم وإدارة المعارض والمؤتمرات', 'استزراع الربيان في البحار',
#        'الأسواق المركزية للمواد الغذائية والاستهلاكية',
#        'مناولة وقود وزيت الطائرات',
#        'البيع بالجملة للطابوق والبلك والبلاط والحجر والرخام والسيراميك والبورسلان',
#        'مراكز العلاج الطبيعي',
#        'إصلاح وصيانة محطات الطاقة الكهربائية والمحولات',
#        'البيع بالتجزئة عن طريق الانترنت',
#        'التسجيل لتقديم خدمات الحوسبة السحابية',
#        'تركيب انظمة التدفئة بالكهرباء اوالغاز اوالزيت وصيانتها واصلاحها',
#        'محلات تقديم المشروبات ( الكوفي شوب )',
#        'أنشطة الاستشارات في مجال الأعمال الدولية', 'أنشطة النسخ والتصوير',
#        'أنشطة خدمات صيانة المباني', 'الصالات والمراكز الرياضية الرجالية',
#        'صناعة الأثاث والموبيليا من الخشب',
#        'صناعة المركبات أو العربات المدفوعة باليد',
#        'تجارة الجملة والتجزئه في أنواع أخرى من المركبات ذات المحركات لم ترد فيما سبق',
#        'تركيب وصيانة أجهزة ومعدات الإطفاء',
#        'البيع بالتجزئة للأجهزة والمعدات والمستلزمات الطبية',
#        'البيع بالجملة للفواكة والثمار الزيتية', 'نقل نفايات البلدية',
#        'تلميع السيارات (البوليش)',
#        'البيع بالتجزئة للمعدات الرياضية والصيد والدراجات الهوائية وغيرها',
#        'المجمعات الطبية المتخصصة',
#        'شراء وبيع الاراضى والعقارات وتقسيمها وأنشطة البيع على الخارطة',
#        'تصميم وبرمجة البرمجيات الخاصة', 'إصلاح وصيانة السدود',
#        'إصلاح وصيانة الطرق والشوارع والأرصفة ومستلزمات الطرق',
#        'إصلاح وصيانة أجهزة الهواتف المحمولة (الجوال)', 'مراكز طب الاسنان',
#        'البيع بالجملة للأدوات المكتبية (القرطاسية)',
#        'مراكز التحاليل الطبية', 'الاستشارات الهندسية للتخطيط الحضري',
#        'إنشاءات المباني الجاهزة في المواقع',
#        'مختبرات القياس والمعايرة والتحقق',
#        'خدمات شحن وتفريق السلع بصفة عامة', 'البيع بالجملة للشعير  ',
#        'البيع بالتجزئة للادوات المنزلية والمشغولات اليدوية المتنوعة (أدوات القطع، والخزفيات، والأواني الزجاجيه والفخارية... الخ)',
#        'إدارة مرافق الإيواء السياحي', 'أنشطة التصدير والاستيراد',
#        'البيع بالتجزئة للعود والبخور',
#        'تجفيف وتعبئة التمور وصناعة منتجاتها',
#        'معاهد الشراكات الاستراتيجية',
#        'المؤسسات والهيئات الدينية غير ما ذكر فيما سبق .',
#        'صناعة الخزائن الحديدية', 'التعليم المتوسط للطلاب بمنهج وطني',
#        'البيع بالتجزئة للملابس الرياضية',
#        'صناعة المطهرات للاستخدام الزراعي',
#        'أنشطة التطهير والتبخير لإبادة الحشرات والقوارض',
#        'مراكز الاسترخاء والعناية الشخصية',
#        'البيع بالجملة للهدايا والكماليات', 'معاهد التدريب الإداري',
#        'البيع بالجملة لالعاب الأطفال', 'وكلاء البيع في مستحضرات التجميل',
#        'البيع بالجملة للماكينات المحاسبية والإحصائية والكتابية ومعدات المكاتب ولوازمها',
#        'البيع بالجملة والتجزئة لاجزاء وتوابع المركبات لم ترد فيما سبق',
#        'البيع بالجملة عن طريق الانترنت',
#        'البيع بالجملة للأدوات الصحية وتمديداتها وسخانات وصهاريج المياه',
#        'مراكز الإشراف والتدريب التربوي الأهلي', 'الصالونات النسائية',
#        'البيع بالجملة للأجهزة والمعدات والمستلزمات الطبية',
#        'إنشاء المطارات ومرافقها', 'إصلاح الأجهزة الإلكترونية الاستهلاكية',
#        'صناعة أصناف مصنوعة من الأسلاك ، يشمل ( سلك شائك ، سياج ، شبك ممدد ... الخ )',
#        'أنشطة المتعهدين الذين يقدمون خدمات الطعام',
#        'البيع بالتجزئة لمنتجات المخابز والحلويات السكرية',
#        'صناعة التركيبات للمحلات والمطاعم ، يشمل ( تركيب ديكورات وما شابهها )',
#        'المجمعات الطبية العامة',
#        'تجارة الحلوى ، تشمل ( الحلوى العمانية والبحرينية )',
#        'تقديم العصائر الطازجة و المشروبات الباردة',
#        'التشغيل الطبي للمجمعات الطبية ومراكز جراحة اليوم الواحد',
#        'البيع بالجملة للمعدات والتجهيزات الأمنية (للمنافسات الحكومية فقط)',
#        'تقديم الخدمات اللوجستية البريدية', 'ورش صناعة الالمونيوم',
#        'الأندية الرياضية',
#        'البيع بالتجزئة لمعدات فحص النظر (محلات النظارات )',
#        'البيع بالجملة للشوكلاته والكاكاو', 'البيع بالتجزئة للأحذية',
#        'تأجير سيارات ركاب بدون سائق', 'البيع بالتجزئة للأثاث المكتبي',
#        'التعليم الثانوي للطلاب بمنهج وطني',
#        'التعليم في مرحلة ما قبل المدرسة - رياض الأطفال بمنهج عالمي',
#        'البيع بالجملة للأغذية والمشروبات', 'تغطية الارضيات خشب الباركيه',
#        'البيع بالتجزئة للمعادن الثمينة والأحجار الكريمة',
#        'البيع بالتجزئة للوكلاء بالعمولة بدون محلات',
#        'البيع بالتجزئة للحوم ومنتجات اللحوم',
#        'صناعة المستحضرات الصيدلانية للاستخدام البشري',
#        'صناعة الحلاوة الطحينية',
#        'تركيب وصيانة الوحدات المسبقة الشد لإجهادات الخرسانة',
#        'البيع بالتجزئة للملابس الجاهزة الرجالية',
#        'رعاية وصيانة مناظر المباني والحدائق المنزلية وحدائق الأسقف وواجهات المباني الخاصة وغيرها',
#        'البيع بالجملة والتجزئة لقطع الغيار المستعملة للسيارات وتوابعها',
#        'التنظيف العام للمباني',
#        'تقديم خدمات الاستشارات الهندسية في مجال الوقاية والحماية من الحريق',
#        'رعاية وصيانة منتزهات الطرق السريعة',
#        'التوسط في استقدام العمالة الوافدة',
#        'صناعة منتجات نصف مصنعة من اللدائن ، يشمل ( ألواح ، شرائح ، صفائح ، أشرطة ، مواسير وخراطيم ولوازمها ... الخ )',
#        'بيع الألعاب واللّعب بالتجزئة في المتاجر المتخصصة',
#        'سيارة متجولة لبيع الأغذية',
#        'انتاج الشكولاته بالحليب والشوكلاته البيضاء والغامقة وغيرها من أنواع الشوكلاته',
#        'تشغيل مرافق الفعاليات الترفيهية', 'البيع بالتجزئة للأثاث المنزلي',
#        'البيع بالتجزئة للكماليات وللإكسسوارات الملابس، يشمل (القفازات وأربطة العنق والحمالات والسبح والمظلات)',
#        'البيع بالتجزئة لأصناف العبايات النسائية والفراء',
#        'صناعة أجهزة تكييف الهواء (وحدات أو مركزي ) فريون',
#        'تركيب الزجاج والمرايا للمباني',
#        'خدمات المكاتب العلمية والفنية للمنتجات عدا المستحضرات الصيدلانية',
#        'تأجير السيارات بسائق', 'بيع معدات ضخ المياه',
#        'تمديد اسلاك الاتصالات', 'تقطيع وشطف الزجاج العادي',
#        'تقديم خدمة إدارة ومراقبة شبكات الاتصالات والمعلومات',
#        'أنشطة تعقيب المعاملات',
#        'البيع بالتجزئة للأجهزة المخبرية والتشخيصية الطبية',
#        'البيع بالتجزئة لمستحضرات التجميل وصابون الزينة',
#        'حفظ الأسماك والمنتجات السمكية بواسطة التبريد أو التجميد',
#        'استيراد المعادن الثمينة والأحجار الكريمة',
#        'البيع بالجملة للملابس الجاهزة',
#        'البيع بالجملة للنجف وأصناف الإضاءة', 'أنشطة التخليص الجمركي',
#        'المصارف المركزية', 'أنشطة وكالات النقل والشحن البحري',
#        'البيع بالتجزئة لوقود السيارات والدراجات النارية (محطات الوقود)',
#        'صنع أنابيب ومواسير وأشكال مجوفة ووصلات أنابيب أو مواسير',
#        'تقديم خدمات الاستشارات الإدارية العليا', 'أنشطة الوساطة التجارية',
#        'صيانة برمجيات وتصميم صفحات المواقع',
#        'التأمين ضد المرض وحوادث العمل والبطالة',
#        'البيع بالجملة للخشب بجميع أنواعه', 'خدمات الاختبارات والتقييم',
#        'التعليم المتوسط للطالبات بمنهج وطني',
#        'أصحاب المعدات وسائقي النقل (خاصة)', 'التمويل الاستهلاكي',
#        'تشغيل خدمات تقديم الطعام في المرافق الرياضية وما شابهها على أساس إمتياز محدد',
#        'صناعة الأوعية المعدنية المستخدمة في نقل وتعبئة السلع ، يشمل ( البراميل وحاويات النفايات والمخلفات والدلاء والصناديق والعلب ... الخ )',
#        'البيع بالجملة للنباتات الخارجية',
#        'تأجير زوارق المتعة مع بحارتها ، يشمل ( تأجير زوارق رحلات الصيد )',
#        'نقل الطرود (محلي)', 'تنظيف المباني الجديدة بعد الإنشاء',
#        'إدارة عمليات الصيانة والتشغيل في المباني والمرافق التابعة لھا',
#        'نقل وتوزيع المياه',
#        'تركيب شبكات الطاقة الشمسية وصيانتها واصلاحها',
#        'مراكز خدمات النقل الاسعافي', 'الجمعيات والهيئات الدينية',
#        'أنشطة العيادات البيطرية',
#        'صناعة منتجات من الحديد أو من الصلب ...الخ ، بواسطة السحب أو البثق أو الدرفلة',
#        'تمديد انابيب النفط والغاز', 'أنشطة وكالات شركات الطيران',
#        'إصلاح وصيانة الجسور والأنفاق', 'تسجيل علامات تجارية',
#        'الاستشارات الهندسية للطرق والجسور والانفاق',
#        'أنشطة أخرى لأنشطة البيع بالجملة والتجزئة لقطع غيار السيارات وتوابعها ، يشمل ( تنجيد السيارات )',
#        'إدارة وتاجير العقارات المملوكة أو المؤجرة (سكنية )',
#        'البيع بالتجزئة للأجهزة الالكترونية والكهربائية المنزلية',
#        'الشقق المخدومة', 'الوحدات السكنية المفروشة',
#        'البيع بالجملة لقطع الغيار الخاصة بأجهزة التكييف والتبريد',
#        'البيع بالتجزئة لأوراق الجدران واغطية الارضيات',
#        'تصميم المواقع الاكترونية',
#        'البيع بالجملة لمستحضرات وصابون التجميل',
#        'تشغيل المدارس المستقلة (التعليم الثانوي) بمنهج وطني',
#        'صناعة الأبواب والنوافذ الخشبية', 'خدمات الحراس الشخصيين',
#        'إصلاح وصيانة المنتجات الجلدية كالأمتعة والحقائب',
#        'اصلاح وصيانة المحركات والمولدات الكهربائية وأجهزة التوليد البخارية',
#        'البيع بالجملة للمجوهرات',
#        'البيع بالتجزئة لأجهزة ومعدات ومواد الوقاية والحماية من الحريق',
#        'صناعة البلاستيك (اللدائن ) في أشكالها الأولية',
#        'صناعة الحلويات الشعبية والشرقية بمختلف أنواعها',
#        'البيع بالجملة للتمور', 'البيع بالجملة لمنتجات القهوة والشاي',
#        'البيع بالتجزئة للادوات الكهربائية وتمديداتها',
#        'صناعة وتجميع آلات ومعدات مناولة زراعية',
#        'أنشطة الاستشارات في مجال الاتصالات وتقنية المعلومات',
#        'البيع بالجملة للأثاث المنزلي والموبيليا',
#        'انتاج شراب السكر المسحوق (الكراميل) والشيرة',
#        'البيع بالجملة للأجهزة الأمنية', 'بيع الأعشاب الطبية الطبيعية',
#        'امتلاك العقارات والمنقولات اللازمة للشركات القابضة',
#        'الكيانات القانونية المنظمة الأخرى',
#        'إدارة وتاجير العقارات المملوكة او المؤجرة (غير سكنية )',
#        'إصلاح آلات ومعدات مناولة المعادن', 'تحميص وتعبئة المكسرات',
#        'تركيب وتمديد انابيب تكييف الهواء وصيانتها واصلاحها',
#        'البيع بالتجزئة للزي الموحد', 'نقل السوائل او الغازات السائلة',
#        'البيع بالتجزئة للعطور',
#        'إنشاء وإقامة محطات الطاقة الكهربائية والمحولات',
#        'صناعة وتشكيل قضبان حديد التسليح',
#        'تشغيل مناجم الرمال أو الحصباء ، يشمل ( الكسارات )',
#        'البيع بالتجزئة لألواح الزجاج', 'معاهد التدريب العالي',
#        'إصلاح محاور وفرامل السيارات',
#        'البيع بالتجزئة للرخام والحجر الطبيعي والاصطناعي والسيراميك والبورسلان',
#        'الجمعيات التعاونية', 'النقل الجوي للبضائع المحدد بمواعيد',
#        'مطابخ إعداد الولائم للحفلات',
#        'إنشاء محطات ومشاريع الصرف الصحي وشبكات المجاري والمضخات',
#        'مراكز العلاج والتأهيل النفسي',
#        'قصور وصالات الافراح والمناسبات مع الاقامة',
#        'البيع بالجملة للحواسيب ومستلزماتها ، يشمل (بيع الطابعات وأحبارها)',
#        'صناعة الحلويات السكرية ، يشمل ( الملبس و الكراميل والتوفي والنوغا " راحة الحلقوم" )',
#        'البيع بالتجزئة للملابس الجاهزة النسائية',
#        'نقل السلع المبردة والمجمدة',
#        'تأجير لوازم المناسبات (خيم المناسبات، كوش الافراح ...وغيرها)',
#        'مصنوعات معدنية عادية غير حديدية ، يشمل ( (أسلاك ، مواسير ، أنابيب ، مساحيق ، أوراق ، صفائح ...الخ )',
#        'انتاج اللحوم المبردة والمجمدة', 'التعليم الابتدائي',
#        'صناعة الأثاث لكافة الأغراض من البلاستيك واللدائن',
#        'البيع بالتجزئة لسكراب مواد البناء (يشمل تجارة الحديد الخردة)',
#        'البيع بالتجزئة للقوارب والدراجات الهوائية وغيرها',
#        'إدارة المال وحفظه للمركبات',
#        'أنشطة النداءات الخارجية التي تستعمل طرقاً مماثلة لبيع أو تسويق السلع أو الخدمات للعملاء المحتملين، والقيام بأبحاث السوق أو استطلاعات الرأي العام وغير ذلك من الأنشطة لصالح العملاء',
#        'أنشطة مراكز خدمات وصيانة السيارات',
#        'أنواع النقل البري الغير المحددة بمواعيد',
#        'البيع بالجملة والتجزئة لقطع الغيار الجديده للسيارات وتوابعها (وتشمل زينة السيارات)',
#        'البيع بالتجزئة للمكسرات والبن والتوابل والعطارة',
#        'أنشطة إيواء الحيوانات مع تقديم الرعاية الصحية اللازمة والعلاج',
#        'تنظيم أنشطة قطاع الأعمال والمساهمة في تحسين عملياته',
#        'صناعة الكيماويات العضوية الأساسية ، يشمل الاستلين عدا الأسمدة والمركبات الأزوتيه ( النتروجينية )',
#        'البيع بالجملة للمولدات والمحولات الكهربائية',
#        'البيع بالجملة لقطع غيار الهواتف النقالة',
#        'أنشطة الخطاطين والرسامين',
#        'أنشطة تصميم الازياء والملبوسات والاحذية والمجوهرات',
#        'أنشطة المراجعة وتدقيق الحسابات',
#        'ترميمات المباني (التاريخية والتراثية والأثرية)',
#        'دور الرعاية مع الإقامة لذوي الاحتياجات الخاصة',
#        'صناعة الملابس الرجالية الجاهزة ، يشمل ( الثياب الجاهزة والبدل والمعاطف والبنطلونات )',
#        'تجارة التجزئة في السلع الشخصية في الأسواق الكبيرة والتي تعمل ضمن إدارة واحدة ، يشمل ( الملابس والأحذية والسلع الجلدية والعطور ومستحضرات التجميل والمجوهرات والاكسسوارات والأجهزة والأدوات المنزلية وألعاب الأطفال والأدوات الرياضية, الخ)',
#        'إنشاء الجسور والانفاق', 'مراكز البحوث والدراسات الاجتماعية',
#        'الاستشارات الهندسية للمياه والصرف الصحي',
#        'أنشطة خدمات التنظيف للمباني الحكومية',
#        'صناعة الورق والورق المقوى المموج (الكرتون)',
#        'البيع بالجملة لمنتجات الألبان',
#        'صناعة الحشو من المواد النسيجية ، يشمل ( الحفاظات الصحية ، وسدات قطنية لوقف النزيف )',
#        'المخازن العامة التي تضم مجموعة متنوعة من السلع',
#        'مختبرات التشييد ومواد البناء',
#        'أنشطة الاستشارات في مجال الحاسب الآلي', 'خدمات مناولة الحاويات',
#        'تنظيف متخصص للمباني ، يشمل المداخن والنوافذ وغيرها',
#        'البيع بالتجزئة للثريات والنجف والسلع المستخدمة في الإضاءة ومستلزماتها',
#        'مؤسسات ووكالات الدعاية والاعلان', 'إستشارات الهندسة الالكترونية',
#        'البيع بالتجزئة للأنابيب المعدنية والحديدية',
#        'وسطاء تأجير السيارات',
#        'صناعة بلاط الحوائط والأرضيات (السيراميك والقيشاني)',
#        'أنشطة أخرى من المقاهي', 'غسيل وتشحيم السيارات',
#        'البيع بالجملة للاكسسوارات المعدنية والاقفال والمفصلات وغيرها',
#        'صناعة المواد الدوائية المستخدمة في صنع الأدوية',
#        'تعبئة وحفظ البقوليات (المطبوخة وغير المطبوخة) بالتعليب',
#        'أنشطة مستودعات الأدوية',
#        'انتاج أحجار رحى الطواحين وأحجار السن والصقل والشحذ',
#        'صناعة أعلاف الحيوانات الأليفة', 'تقديم خدمة مراكــز الاتصـال',
#        'مراكز التوزيع للأغذية والمشروبات',
#        'البيع بالتجزئة لمنتجات الديكور والاسقف الصناعية والمواد العازلة ومواد البناء',
#        ' مستشفيات الرعاية الطبية الممتدة والنقاهة',
#        'أنشطة الاستشارات البيئية', 'البيع بالتجزئة للشوكولاتة و الكاكاو',
#        'العيادات الطبية العامة الأخرى',
#        ' تجارة الجملة والتجزئة - تكنولوجيا، والآلات والملابس والخدمات وغيرها',
#        'البيع بالتجزئة لمواد البناء ، يشمل ( الأسمنت ، البلك ، الجبس ، البلاط الأسمنتي... الخ )',
#        'البيع بالجملة لأنواع الوقود السائلة ، يشمل ( بيع البترول الخام ومنتجات تكرير البترول )',
#        'أنواع أخرى من تجارة الجملة والتجزئة للمركبات ذات المحركات لم ترد فيما سبق ، يشمل ( المركبات الجديدة والمستعملة )',
#        'تأجير المعدات ذات المحركات',
#        'نقل الركاب بالحافلات داخل المدن                ',
#        'بيع الأدوية البيطرية ، يشمل ( معدات البيطرية )',
#        'أنشطة حاضنات ومسرعات الأعمال', 'صناعة وتركيب السقالات',
#        'التعليم الثانوي للطالبات بمنهج عالمي',
#        'إقامة البنية الأساسية لاستضافة المواقع على الشبكة وخدمات تجهيز البيانات والأنشطة المتصلة بذلك',
#        'التخلص النهائي من الزيوت المستعملة',
#        'التخزين في الموانىء والمناطق الجمركية أوالحرة',
#        'أنشطة الاستشارات الإدارية',
#        'إصلاح وصيانة معدات القياس والاختبار والمراقبة والتحكم',
#        'البيع بالتجزئة لأصناف أخرى خاصة بتجارة التجزئة في الخردوات المعدنية والدهانات ومواد الإنشاءات ، يشمل ( أبواب الكراجات وغيرها )',
#        'التشغيل الطبي للمستشفيات',
#        'أنشطة وكالات التشغيل المؤقت لخدمات المنزلية',
#        'انتاج وتعبئة المياه المعدنية بالموقع', 'الوساطة العقارية',
#        'أنشطة الاستشارات في مجال الزكاة وضريبة الدخل'], dtype=object)

# %%
fff.head(50)
# Out:
#                            job_title      job_date  \
# 3                    ميكانيكي سيارات    27/05/1444
# 25                          مدير عام    26/05/1444
# 40                          مدير فرع    25/05/1444
# 42                 موظف استقبال فندق    25/05/1444
# 47                              بائع    25/05/1444
# 48                              بائع    25/05/1444
# 49         أخصائي عمليات موارد بشرية    25/05/1444
# 50                 أخصائي خدمة عملاء    25/05/1444
# 51                              بائع    25/05/1444
# 52                       أخصائي جودة    25/05/1444
# 53                   معلم صفوف أولية    25/05/1444
# 54                              بائع    03/05/1444
# 281                       سائق سيارة    23/04/1444
# 617            بائع مأكولات ومشروبات    30/04/1444
# 693                 مساعد طبيب أسنان    14/05/1444
# 694                     موظف استقبال    14/05/1444
# 695                            محاسب    21/05/1444
# 710                     مندوب مبيعات    20/05/1444
# 732                       مدير إداري    19/05/1444
# 740                             محصل    19/05/1444
# 742                      رئيس تنفيذي    19/05/1444
# 758                مدير شؤون قانونية    18/05/1444
# 759                 كاتب موارد بشرية    18/05/1444
# 760                      مدخل بيانات    18/05/1444
# 761                            مترجم    18/05/1444
# 762     مدير موارد بشرية أمن سيبراني    18/05/1444
# 807                      مساعد إداري    28/05/1444
# 810                             بائع    28/05/1444
# 812                             بائع    28/05/1444
# 837                            محاسب    27/05/1444
# 856                            صيدلي    24/05/1444
# 857                     أخصائي تسويق    24/05/1444
# 860                موظف استقبال فندق    22/05/1444
# 866                موظف استقبال فندق    05/06/1444
# 881                موظف استقبال فندق  Publish date
# 889                     أخصائي تسويق  Publish date
# 892                 كاتب موارد بشرية  Publish date
# 905                     موظف استقبال  Publish date
# 910                موظف استقبال فندق  Publish date
# 916                             بائع  Publish date
# 930                      منسق منتجات    09/06/1444
# 931                            صيدلي    09/06/1444
# 947            أخصائي استشارات أعمال    08/06/1444
# 949                    أخصائي بصريات    08/06/1444
# 952                موظف استقبال فندق    08/06/1444
# 961                     أخصائي تسويق    07/06/1444
# 975                       مدير إداري    02/06/1444
# 1046  كاتب استعلامات مركز خدمة عملاء    04/06/1444
# 1101                           محاسب    09/06/1444
# 1102                           محاسب    09/06/1444
#
#                                                job_desc  \
# 3     ['تشخيص أعطال السيارات وإصلاحها وتنفيذ برامج ا...
# 25    ['المشاركة في وضع الأهداف العامة والسياسات وال...
# 40    ['المشاركة في وضع وإعداد أهداف الفرع في ضوء تو...
# 42    ['الإشراف على خدمات الضيوف في مكتب الاستقبال، ...
# 47    ['بيع مجموعة من السلع والخدمات للعملاء، وتوفير...
# 48    ['بيع مجموعة من السلع والخدمات للعملاء، وتوفير...
# 49    ['تنفيذ الإجراءات والأنظمة والنماذج الخاصة بمر...
# 50    ['وضع وتحديد مؤشرات ومعايير الأداء والجودة في ...
# 51    ['بيع مجموعة من السلع والخدمات للعملاء، وتوفير...
# 52    ['تصميم أدلة ونماذج إدارة الجودة، وتطبيق معايي...
# 53    ['تخطيط وتحضير الدروس للصفوف الأولية وتدريسهم ...
# 54    ['بيع مجموعة من السلع والخدمات للعملاء، وتوفير...
# 281   ['تولي مهمة قيادة السيارة بغرض القيام بالأعمال...
# 617   ['بيع المأكولات و المشروبات للزبائن، وتوفير ال...
# 693   ['تحضير المواد السنية وخلط الحشوات ومنأولة طبي...
# 694   ['الوظفيه في عياده بيطريه مخصصه للقطط والكلاب ...
# 695   ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
# 710   ['جمع البيانات والمواصفات المتعلقة بالمنتجات (...
# 732   ['المشاركة في تطوير الأهداف الرئيسية للشؤون ال...
# 740   ['إعداد كشوفات بالجهات والاشخاص وبالإيرادات وا...
# 742   ['المشاركة في وضع الأهداف والخطط الإستراتيجية ...
# 758   ['إعداد وتخطيط وتوجيه كافة الأمور المتعلقة بال...
# 759   ['الحفاظ على سجلات الموظفين وتحديثها، وإعداد ا...
# 760   ['مراجعة استمارات البيانات وتدقيقها، وإدخال وت...
# 761   ['دراسة العلوم اللغوية بلغتين على الأقل مثل: ا...
# 762   ['تطوير الخطط والاستراتيجيات و الإرشادات داخل ...
# 807   ['متابعة تنفيذ القرارات الادارية الصادرة عن ال...
# 810   ['بيع مجموعة من السلع والخدمات للعملاء، وتوفير...
# 812   ['بيع مجموعة من السلع والخدمات للعملاء، وتوفير...
# 837   ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
# 856   ['دراسة التركيبات الدوائية للعقاقير والعلاجات ...
# 857   ['تحديد الأهداف وتطوير السياسات التسويقية للسل...
# 860   ['الإشراف على خدمات الضيوف في مكتب الاستقبال، ...
# 866   ['الإشراف على خدمات الضيوف في مكتب الاستقبال، ...
# 881   ['الإشراف على خدمات الضيوف في مكتب الاستقبال، ...
# 889   ['تحديد الأهداف وتطوير السياسات التسويقية للسل...
# 892   ['الحفاظ على سجلات الموظفين وتحديثها، وإعداد ا...
# 905   ['استقبال الزوار والعملاء وتحديد مطالبهم وتوجي...
# 910   ['الإشراف على خدمات الضيوف في مكتب الاستقبال، ...
# 916   ['بيع مجموعة من السلع والخدمات للعملاء، وتوفير...
# 930   ['تخطيط طريقة عرض المنتجات في مكان العرض وتنسي...
# 931   ['دراسة التركيبات الدوائية للعقاقير والعلاجات ...
# 947   ['الشؤون الصحية بوزارة الحرس الوطني تبحث عن اخ...
# 949   ['تجهيز النظارات الطبية بحسب نتائج الفحص أو وص...
# 952   ['الإشراف على خدمات الضيوف في مكتب الاستقبال، ...
# 961   ['تحديد الأهداف وتطوير السياسات التسويقية للسل...
# 975   ['تطوير الأهداف الرئيسية للشؤون الإدارية، والإ...
# 1046  ['تقديم المشورة والمعلومات الأساسية للعملاء، و...
# 1101  ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
# 1102  ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
#
#                                               job_tasks  \
# 3     ['   فحص أداء المعدّات الكهربائية والميكانيكية...
# 25    ['   المشاركة في وضع الأهداف والسياسات والمباد...
# 40    ['   المشاركة في وضع وإعداد الخطط والأهداف الخ...
# 42    ['   الحفاظ على قائمة الحجوزات، وتوفير السجلات...
# 47    ['1- إستقبال الزبائن وعمل أوامر الطلبات ', '2-...
# 48    ['   بيع مجموعة من السلع والخدمات للعملاء.', '...
# 49    ['   تنفيذ الإجراءات والأنظمة والنماذج الخاصة ...
# 50    ['   إجراء الدراسات والتحاليل المتخصصة بهدف وض...
# 51    ['- تحقيق هدف المبيعات الشهري.                ...
# 52    ['   دراسة وتحليل وإعداد وتصميم أدلة ونماذج إد...
# 53    ['   تحضير الدروس الخاصةبالصفوف الأولية وفقاً ...
# 54    ['   بيع مجموعة من السلع والخدمات للعملاء.', '...
# 281   ['نقل الحالات إلى كافة المواعيد مستشفى , نيابة...
# 617   ['   بيع المأكولات و المشروبات للزبائن.', '  ت...
# 693   ['   استقبال المريض واجلاسه على كرسي طب الاسنا...
# 694   ['   استقبال الزوار والعملاء والترحيب بهم وتحد...
# 695   ['   تدقيق المطالبات المالية والتأكد من اكتمال...
# 710   ['   بناء قاعدة بينات للعملاء الحاليين والمرتق...
# 732   ['   المشاركة في تطوير الأهداف الرئيسية للشؤون...
# 740   ['   إعداد كشوفات بالمبالغ المستحقة من الجهات ...
# 742   ['   المشاركة في وضع الإستراتيجية العامة وتحقي...
# 758   ['   إعداد وتطوير الخطط الفرعية والبرامج التنف...
# 759   ['   حفظ سجلات الموظفين، وتحديثها، وتسجيل البي...
# 760   ['   مراجعة الاستمارات المتعلقة بالبيانات وترم...
# 761   ['   دراسة أصول وقواعد ومصطلحات اللغة الأم من ...
# 762   ['   إجراء تقييمات احتياجات التعلّم وتحديد الم...
# 807   ['   تنفيذ التعليمات الادارية الصادرة عن الرئي...
# 810   ['   بيع مجموعة من السلع والخدمات للعملاء.', '...
# 812   ['   بيع مجموعة من السلع والخدمات للعملاء.', '...
# 837   ['   تدقيق المطالبات المالية والتأكد من اكتمال...
# 856   ['   دراسة مواصفات وتركيبات الادوية والعقاقير ...
# 857   ['   تحديد الأهداف العامة والفرعية للتسويق وتط...
# 860   ['   الحفاظ على قائمة الحجوزات، وتوفير السجلات...
# 866   ['   الحفاظ على قائمة الحجوزات، وتوفير السجلات...
# 881   ['   الحفاظ على قائمة الحجوزات، وتوفير السجلات...
# 889   ['   تحديد الأهداف العامة والفرعية للتسويق وتط...
# 892   ['   حفظ سجلات الموظفين، وتحديثها، وتسجيل البي...
# 905   ['   استقبال الزوار والعملاء والترحيب بهم وتحد...
# 910   ['   الحفاظ على قائمة الحجوزات، وتوفير السجلات...
# 916   ['   بيع مجموعة من السلع والخدمات للعملاء.', '...
# 930   ['   تخطيط طريقة تنسيق المنتجات في مكان العرض،...
# 931   ['   دراسة مواصفات وتركيبات الادوية والعقاقير ...
# 947   ['   تقديم استشارات  لتطوير الأهداف الرئيسيةفي...
# 949   ['   اختيار إطار النظارة بالتنسيق مع صاحب العل...
# 952   ['   الحفاظ على قائمة الحجوزات، وتوفير السجلات...
# 961   ['   تحديد الأهداف العامة والفرعية للتسويق وتط...
# 975   ['تطوير الأهداف الرئيسية للشؤون الإدارية، وتطو...
# 1046  ['   الرد على الأسئلة والاستعلامات الأساسية لل...
# 1101  ['   تدقيق المطالبات المالية والتأكد من اكتمال...
# 1102  ['   تدقيق المطالبات المالية والتأكد من اكتمال...
#
#                                               comp_name     comp_no  \
# 3                               مؤسسة لمكو لغيار الزيوت   8-1925495
# 25                ورشة اضواء المشاعل للحدادة والالمنيوم  10-2010602
# 40                                    شركة الزي للتجارة   9-2079452
# 42                             فندق قصر الواحة الفندقية   1-2440535
# 47                شركة مطعم بيت الشاورما لتقديم الوجبات   1-2239765
# 48                            شركة أطياب غناتي التجارية  29-1959880
# 49    شركة الصخرة المشرفة والسارية الخضراء للاستشارا...    1-321449
# 50                                   شركة بروج للكابلات   1-2500658
# 51                     شركة المشروبات والاطعمة الغذائية   1-2432212
# 52            شركة مصنع الجواد للبلاستيك والتغليف المرن   8-1971512
# 53                        مدارس  الأختيار الاول الاهلية   1-1384889
# 54                                شركة جبو رية للحلويات   3-1955781
# 281                          جمعية حماية الاسرة الخيرية    9-191343
# 617                  مقهى الفصل الخامس لتقديم المشروبات  20-1955938
# 693              مجمع أطباء العناية الطبي شركة شخص واحد  13-1982911
# 694                  شركة رعايه للتجارة (شركة شخص واحد)   1-2000087
# 695                           شركة رزانة لتشغيل الفنادق  13-2001145
# 710   شركة ياسر محمد احمد بقشان لوساطة التامين واعاد...    9-160776
# 732   شركة صيدلية جمال الدين خوجة المركزية وشريكه ال...  13-1995317
# 740                     مكتب سرعة التحصيل لتحصيل الديون  15-1963187
# 742           جاروديه الخيريه للخدمات الاجتماعيه /جمعيه     EST-282
# 758             شركة رتيل الشرق للمقاولات شركة شخص واحد   1-2617191
# 759             شركة رتيل الشرق للمقاولات شركة شخص واحد   1-2617191
# 760             شركة رتيل الشرق للمقاولات شركة شخص واحد   1-2617191
# 761             شركة رتيل الشرق للمقاولات شركة شخص واحد   1-2617191
# 762             شركة رتيل الشرق للمقاولات شركة شخص واحد   1-2617191
# 807                    شركة اركي المحدودة شركة شخص واحد   1-2226342
# 810                    تموينات نهال نجد للمواد الغذائية   1-2011581
# 812                       مؤسسة قيادة المباني للمقاولات   1-2524485
# 837                   شركة ورشة التشكيل المعدني للحدادة   9-2115642
# 856                                        صيدلية ماربل  10-1990591
# 857                             مؤسسة لمكو لغيار الزيوت   8-1925495
# 860                            نسمة بحر للوحدات السكنية  22-1681489
# 866                          فندق صفوة الغفران الفندقية    13-84812
# 881                                  فندق ظاظا الفندقية   9-2126602
# 889                     شركة رفا الطبية (شركة شخص واحد)    1-362446
# 892   الفلاح الراقي للوحدات السكنية المفروشة لصاحبته...    13-85391
# 905                             معهد الجودة بلس للتدريب   9-2088192
# 910                          فندق صفوة الغفران الفندقية    13-84812
# 916                      أسواق المسارات الرائعة للتجارة  11-2011773
# 930    صيدليه السوسن الجديده لصاحبها سراج عمر سراج عابد     9-97451
# 931    صيدليه السوسن الجديده لصاحبها سراج عمر سراج عابد     9-97451
# 947                 برنامج مستشفى الملك فهدللحرس الوطني    EST-1237
# 949    شركة الدكتور حامد سليمان الاحمدي وشركاه المحدوده  10-1673172
# 952                                  فندق ظاظا الفندقية   9-2126602
# 961                     شركة رفا الطبية (شركة شخص واحد)    1-362446
# 975          شركة الرعاية الموثوقة الطبية شركة شخص واحد   1-2466520
# 1046                        شركة الخبير التربوي للتدريب  10-1967416
# 1101                  مؤسسة ساري الليل للمقاولات العامة  19-1951616
# 1102                        شركة أطياف للخدمات المساندة   1-1948186
#
#        comp_type     comp_size eco_activity  \
# 3            خاص   صغيرة فئة ب          NaN
# 25           خاص   صغيرة فئة أ          NaN
# 40           خاص  متوسطة فئة أ          NaN
# 42           خاص   صغيرة فئة ب          NaN
# 47           خاص  متوسطة فئة ج          NaN
# 48           خاص   صغيرة فئة ب          NaN
# 49           خاص  متوسطة فئة ب          NaN
# 50           خاص   صغيرة فئة أ          NaN
# 51           خاص   صغيرة فئة ب          NaN
# 52           خاص  متوسطة فئة ج          NaN
# 53           خاص   صغيرة فئة ب          NaN
# 54           خاص  متوسطة فئة ب          NaN
# 281          خاص   صغيرة فئة ب          NaN
# 617          خاص  متوسطة فئة أ          NaN
# 693          خاص   صغيرة فئة ب          NaN
# 694          خاص   صغيرة فئة ب          NaN
# 695          خاص   صغيرة فئة ب          NaN
# 710          خاص   صغيرة فئة ب          NaN
# 732          خاص   صغيرة فئة ب          NaN
# 740          خاص   صغيرة فئة أ          NaN
# 742   شبه حكومية         كبيرة          NaN
# 758          خاص  متوسطة فئة أ          NaN
# 759          خاص  متوسطة فئة أ          NaN
# 760          خاص  متوسطة فئة أ          NaN
# 761          خاص  متوسطة فئة أ          NaN
# 762          خاص  متوسطة فئة أ          NaN
# 807          خاص  متوسطة فئة أ          NaN
# 810          خاص   صغيرة فئة ب          NaN
# 812          خاص   صغيرة فئة ب          NaN
# 837          خاص   صغيرة فئة ب          NaN
# 856          خاص   صغيرة فئة أ          NaN
# 857          خاص   صغيرة فئة ب          NaN
# 860          خاص   صغيرة فئة أ          NaN
# 866          خاص  متوسطة فئة ب          NaN
# 881          خاص   صغيرة فئة أ          NaN
# 889          خاص   صغيرة فئة ب          NaN
# 892          خاص   صغيرة فئة ب          NaN
# 905          خاص   صغيرة فئة أ          NaN
# 910          خاص  متوسطة فئة ب          NaN
# 916          خاص   صغيرة فئة ب          NaN
# 930          خاص   صغيرة فئة ب          NaN
# 931          خاص   صغيرة فئة ب          NaN
# 947   شبه حكومية         كبيرة          NaN
# 949          خاص         كبيرة          NaN
# 952          خاص   صغيرة فئة أ          NaN
# 961          خاص   صغيرة فئة ب          NaN
# 975          خاص   صغيرة فئة ب          NaN
# 1046         خاص   صغيرة فئة ب          NaN
# 1101         خاص   صغيرة فئة ب          NaN
# 1102         خاص         كبيرة          NaN
#
#                                                  qualif           region  \
# 3     ['Skill data', 'صيانة السيارات وتقييم الاعطال'...  المنطقة الشرقية
# 25    ['Skill data', 'حداد', 'متوسط', 'Language data...  المدينة المنورة
# 40    ['Language data', 'العربية', 'محترف', 'الانجلي...  المنطقة الشرقية
# 42    ['Skill data', 'الاستقبال الفندقي', 'محترف', '...           الرياض
# 47               ['Language data', 'العربية ', 'محترف']           الرياض
# 48                                    ['Language data']           الرياض
# 49                                    ['Language data']           الرياض
# 50                                    ['Language data']           الرياض
# 51    ['Skill data', '-مهارة التواصل مع الآخرين.', '...           الرياض
# 52                      ['Skill data', 'Language data']  المنطقة الشرقية
# 53                                        No requarment           الرياض
# 54                                        No requarment           الرياض
# 281                                       No requarment           الرياض
# 617            ['Language data', 'الانجليزية', 'مبتدئ']             عسير
# 693   ['Skill data', 'التخصص ', 'متوسط', 'Language d...      مكة المكرمة
# 694                     ['Skill data', 'Language data']           الرياض
# 695   ['Skill data', 'comsys ', 'متوسط', 'Language d...      مكة المكرمة
# 710                                       No requarment           الرياض
# 732            ['Skill data', 'مهارات تواصل ', 'مبتدئ']      مكة المكرمة
# 740                                       No requarment  المنطقة الشرقية
# 742   ['Language data', 'العربيه', 'محترف', 'انجليزي...  المنطقة الشرقية
# 758                                       No requarment           الرياض
# 759                                       No requarment           الرياض
# 760                                       No requarment           الرياض
# 761                                       No requarment           الرياض
# 762                                       No requarment           الرياض
# 807                                       No requarment           الرياض
# 810                                       No requarment           الرياض
# 812                                       No requarment           الرياض
# 837   ['Skill data', 'محاسب', 'محترف', 'Language dat...      مكة المكرمة
# 856                                       No requarment  المدينة المنورة
# 857   ['Skill data', 'التسويق', 'محترف', 'Language d...  المنطقة الشرقية
# 860   ['Professional certificate \\ License data', '...            جازان
# 866            ['Language data', 'الانجليزية', 'متوسط']      مكة المكرمة
# 881                                       No requarment      مكة المكرمة
# 889   ['Skill data', 'خبرة سابقة في التسويق الطبي', ...           الرياض
# 892                                       No requarment      مكة المكرمة
# 905   ['Skill data', 'مهارات التسويق - ', 'متوسط', '...      مكة المكرمة
# 910            ['Language data', 'الانجليزية', 'متوسط']      مكة المكرمة
# 916                                       No requarment             عسير
# 930                                       No requarment      مكة المكرمة
# 931   ['Skill data', 'التواصل', 'متوسط', 'الاتصال', ...      مكة المكرمة
# 947     ['Language data', 'اللغة الإنجليزية ', 'محترف']           الرياض
# 949   ['Skill data', 'العمل ضمن فريق', 'محترف', 'موا...  المدينة المنورة
# 952                                       No requarment      مكة المكرمة
# 961   ['Skill data', 'خبرة سابقة في التسويق الطبي', ...           الرياض
# 975   ['Skill data', 'Multitask Performance ', 'محتر...           الرياض
# 1046  ['Skill data', 'شخصية قوية وجذابة', 'محترف', '...  المدينة المنورة
# 1101                                      No requarment  المنطقة الشرقية
# 1102                                      No requarment           الرياض
#
#               city                                           benefits  \
# 3      AL HUFUF...                               ['Salary', '5000.0']
# 25    AL MADINA...                               ['Salary', '4000.0']
# 40      DHAHRAN...  ['Salary', '4500.0', 'Benefits', 'حسب سنوات ال...
# 42    AR RIYADH...  ['Salary', '4500.0', 'Benefits', 'تارقت شهري',...
# 47    AR RIYADH...                               ['Salary', '4000.0']
# 48    AR RIYADH...                               ['Salary', '4000.0']
# 49    AR RIYADH...                               ['Salary', '5000.0']
# 50    AR RIYADH...                               ['Salary', '6000.0']
# 51    AR RIYADH...                               ['Salary', '4000.0']
# 52      AL UYUN...    ['Salary', '4170.0', 'Benefits', 'بدل نقل 400']
# 53    AR RIYADH...                               ['Salary', '4000.0']
# 54    AR RIYADH...  ['Salary', '4500.0', 'Benefits', 'تأمين طبي+ ا...
# 281   AR RIYADH...                               ['Salary', '4500.0']
# 617     TANUMAH...                               ['Salary', '4500.0']
# 693   MAKKAH AL...          ['Salary', '6000.0', 'Benefits', 'اخري ']
# 694   AR RIYADH...                               ['Salary', '4000.0']
# 695   AL HAFAIR...                               ['Salary', '6000.0']
# 710   AR RIYADH...                               ['Salary', '4687.0']
# 732   MAKKAH AL...           ['Salary', '7000.0', 'Benefits', '1000']
# 740   AL KHUBAR...                               ['Salary', '4000.0']
# 742    AL QATIF...                              ['Salary', '10250.0']
# 758   AR RIYADH...                               ['Salary', '4000.0']
# 759   AR RIYADH...                               ['Salary', '4000.0']
# 760   AR RIYADH...                               ['Salary', '4000.0']
# 761   AR RIYADH...                               ['Salary', '4000.0']
# 762   AR RIYADH...                               ['Salary', '5500.0']
# 807   AR RIYADH...                               ['Salary', '4000.0']
# 810   AR RIYADH...                               ['Salary', '4000.0']
# 812   AR RIYADH...                               ['Salary', '4000.0']
# 837      JEDDAH...                               ['Salary', '5000.0']
# 856   AL MADINA...                               ['Salary', '5000.0']
# 857    AL HUFUF...                               ['Salary', '7000.0']
# 860   AL SHUQAY...                               ['Salary', '4200.0']
# 866   MAKKAH AL...                               ['Salary', '4000.0']
# 881   ABU MARAG...                               ['Salary', '4082.0']
# 889   AR RIYADH...                               ['Salary', '5500.0']
# 892   MAKKAH AL...                               ['Salary', '3200.0']
# 905      JEDDAH...                               ['Salary', '4000.0']
# 910   MAKKAH AL...                               ['Salary', '4000.0']
# 916     MUHAYIL...   ['Salary', '3000.0', 'Benefits', 'عمولة مبيعات']
# 930      JEDDAH...           ['Salary', '4000.0', 'Benefits', '1000']
# 931      JEDDAH...           ['Salary', '7500.0', 'Benefits', '1500']
# 947   AR RIYADH...                              ['Salary', '15532.0']
# 949   AL MADINA...  ['Salary', '4667.0', 'Benefits', 'بدل انتقال= ...
# 952   ABU MARAG...                               ['Salary', '4082.0']
# 961   AR RIYADH...                               ['Salary', '5500.0']
# 975   AR RIYADH...  ['Salary', '12000.0', 'Benefits', 'تعتمد على ا...
# 1046  AL MADINA...                               ['Salary', '4000.0']
# 1101  HAFAR AL ...                               ['Salary', '4000.0']
# 1102  AR RIYADH...                               ['Salary', '6000.0']
#
#        contract positions     job_post_id     exper gender
# 3     دوام كامل    0 / 10  20202026350219   0 Years      M
# 25    دوام كامل     0 / 1  20202026348601   0 Years      M
# 40    دوام كامل     0 / 1  20202026347650   2 Years   both
# 42    دوام كامل     0 / 4  20202026347394   2 Years   both
# 47    دوام كامل    0 / 50  20202026346891   0 Years      M
# 48    دوام كامل    0 / 10  20202026346879   2 Years      F
# 49    دوام كامل     0 / 1  20202026346827   0 Years      F
# 50    دوام كامل     0 / 1  20202026346794   2 Years   both
# 51    دوام كامل     0 / 6  20202026346708   0 Years   both
# 52    دوام كامل     0 / 2  20202026346669   0 Years   both
# 53    دوام كامل     0 / 1  20202026346650   0 Years      F
# 54    دوام كامل     0 / 4  20202026310987   0 Years      M
# 281   دوام كامل     0 / 1  20202026274543   2 Years   both
# 617   دوام كامل     0 / 2  20202026310433   0 Years      M
# 693   دوام كامل     1 / 3  20202026334277   0 Years      F
# 694   دوام كامل     0 / 1  20202026334219   0 Years      F
# 695   دوام كامل     0 / 1  20202026343743   2 Years      M
# 710   دوام كامل     0 / 1  20202026342088   2 Years      F
# 732   دوام كامل     0 / 1  20202026340540   0 Years      M
# 740   دوام كامل     0 / 4  20202026339317   0 Years      F
# 742   دوام كامل     0 / 1  20202026339202   0 Years      M
# 758   دوام كامل     0 / 1  20202026338166   0 Years      F
# 759   دوام كامل     0 / 1  20202026338147   0 Years      M
# 760   دوام كامل     0 / 1  20202026338137   0 Years      F
# 761   دوام كامل     0 / 1  20202026338132   0 Years      F
# 762   دوام كامل     0 / 1  20202026338127   2 Years      M
# 807   دوام كامل     0 / 1  20202026352968   0 Years      M
# 810   دوام كامل     0 / 3  20202026352654   2 Years   both
# 812   دوام كامل     0 / 6  20202026352624   0 Years   both
# 837   دوام كامل     0 / 1  20202026350786   4 Years      M
# 856   دوام كامل     0 / 2  20202026346203   0 Years   both
# 857   دوام كامل     0 / 1  20202026345923   4 Years   both
# 860   دوام كامل     0 / 1  20202026344272   0 Years      F
# 866   دوام كامل     0 / 3  20202026375557   0 Years      M
# 881   دوام كامل     0 / 1  20202026379628   0 Years      M
# 889   دوام كامل     0 / 1  20202026377722   2 Years      F
# 892   دوام كامل     0 / 1  20202026377493   0 Years   both
# 905   دوام كامل     0 / 3  20202026375986   0 Years   both
# 910   دوام كامل     0 / 3  20202026375557   0 Years      M
# 916   دوام كامل     0 / 2  20202026374445   0 Years   both
# 930   دوام كامل     0 / 2  20202026390782   0 Years      F
# 931   دوام كامل     0 / 2  20202026390776   0 Years      F
# 947   دوام كامل     0 / 1  20202026390144  10 Years   both
# 949   دوام كامل     0 / 5  20202026390106   0 Years   both
# 952   دوام كامل     0 / 1  20202026379628   0 Years      M
# 961   دوام كامل     0 / 1  20202026377722   2 Years      F
# 975   دوام كامل     0 / 1  20202026368280   4 Years   both
# 1046  دوام كامل     0 / 1  20202026367635   2 Years      F
# 1101  دوام كامل     0 / 1  20202026391571   0 Years      F
# 1102  دوام كامل     0 / 1  20202026391554   0 Years      F

# %%
fff.tail(50)
# Out:
#                            job_title    job_date  \
# 930                      منسق منتجات  09/06/1444
# 931                            صيدلي  09/06/1444
# 947            أخصائي استشارات أعمال  08/06/1444
# 949                    أخصائي بصريات  08/06/1444
# 952                موظف استقبال فندق  08/06/1444
# 961                     أخصائي تسويق  07/06/1444
# 975                       مدير إداري  02/06/1444
# 1046  كاتب استعلامات مركز خدمة عملاء  04/06/1444
# 1101                           محاسب  09/06/1444
# 1102                           محاسب  09/06/1444
# 1103                           محاسب  09/06/1444
# 1104                            سباك  09/06/1444
# 1105              مهندس معماري داخلي  09/06/1444
# 1106                    مهندس معماري  09/06/1444
# 1107                           نجّار  09/06/1444
# 1108                     فني إنشاءات  09/06/1444
# 1109                           محامي  09/06/1444
# 1120                           محاسب  09/06/1444
# 1135                كاتب موارد بشرية  06/06/1444
# 1147                    موظف استقبال  05/06/1444
# 1154                            بائع  05/06/1444
# 1170                    موظف استقبال  01/06/1444
# 1190              مهندس إدارة مشاريع  27/05/1444
# 1242                      محلل مبرمج  18/06/1444
# 1253               موظف استقبال فندق  17/06/1444
# 1259               موظف استقبال فندق  15/06/1444
# 1274               موظف استقبال فندق  13/06/1444
# 1294           فني دعم تقنية معلومات  25/06/1444
# 1296                      مدير إداري  25/06/1444
# 1322                        مدير فرع  21/06/1444
# 1333                           محاسب  20/06/1444
# 1334                   سكرتير تنفيذي  20/06/1444
# 1347                   مهندس كهربائي  19/06/1444
# 1381                           محاسب  09/06/1444
# 1388         فني تدفئة وتهوية وتكييف  02/06/1444
# 1393               موظف صندوق محاسبة  01/07/1444
# 1399               موظف صندوق محاسبة  29/06/1444
# 1401                      وسيط عقاري  29/06/1444
# 1409                           محامي  29/06/1444
# 1411                   أخصائي قانوني  29/06/1444
# 1421                       مدير مالي  29/06/1444
# 1426                        مصفف شعر  29/06/1444
# 1432               موظف صندوق محاسبة  27/06/1444
# 1436               أخصائي علاج طبيعي  26/06/1444
# 1438                            بائع  26/06/1444
# 1444             مشرف مدخلي البيانات  26/06/1444
# 1451                   فني مختبر طبي  25/06/1444
# 1467                           صيدلي  18/06/1444
# 1468             مشغل آلة تشطيب رخام  18/06/1444
# 1469                           صيدلي  18/06/1444
#
#                                                job_desc  \
# 930   ['تخطيط طريقة عرض المنتجات في مكان العرض وتنسي...
# 931   ['دراسة التركيبات الدوائية للعقاقير والعلاجات ...
# 947   ['الشؤون الصحية بوزارة الحرس الوطني تبحث عن اخ...
# 949   ['تجهيز النظارات الطبية بحسب نتائج الفحص أو وص...
# 952   ['الإشراف على خدمات الضيوف في مكتب الاستقبال، ...
# 961   ['تحديد الأهداف وتطوير السياسات التسويقية للسل...
# 975   ['تطوير الأهداف الرئيسية للشؤون الإدارية، والإ...
# 1046  ['تقديم المشورة والمعلومات الأساسية للعملاء، و...
# 1101  ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
# 1102  ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
# 1103  ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
# 1104  ['تحديد المواد اللازمة ومواصفاتها وتقدير الكمي...
# 1105  ['تصميم التعديلات الهيكلية والأثاث والتجهيزات ...
# 1106  ['تصميم المباني الجديدة أو الملحقات أو التعديل...
# 1107  ['أخذ المقاسات من الموقع أو من المخططات والرسو...
# 1108  ['أداء الواجبات الفنية المتعلقة بإنشاء الأبنية...
# 1109  ['دراسة القضية وتجهيز ملفها وجمع البينات الخطي...
# 1120  ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
# 1135  ['الحفاظ على سجلات الموظفين وتحديثها، وإعداد ا...
# 1147  ['استقبال الزوار والعملاء وتحديد مطالبهم وتوجي...
# 1154  ['بيع مجموعة من السلع والخدمات للعملاء، وتوفير...
# 1170  ['استقبال الزوار والعملاء وتحديد مطالبهم وتوجي...
# 1190  ['حاصلا على مؤهلا بدرجة بكالوريوس أو اعلى معتر...
# 1242  ['القيام بالتحليل والبرمجة في تطوير وتنفيذ ودع...
# 1253  ['الإشراف على خدمات الضيوف في مكتب الاستقبال، ...
# 1259  ['الإشراف على خدمات الضيوف في مكتب الاستقبال، ...
# 1274  ['الإشراف على خدمات الضيوف في مكتب الاستقبال، ...
# 1294  ['تقديم الدعم والمساعدة الفنية للموظفين والعمل...
# 1296  ['المشاركة في تطوير الأهداف الرئيسية للشؤون ال...
# 1322  ['المشاركة في وضع وإعداد أهداف الفرع في ضوء تو...
# 1333  ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
# 1334  ['تنظيم المواعيد وإعداد المذكرات وإجراء المراس...
# 1347  ['إعداد التصاميم والمخططات الكهربائية لمشاريع ...
# 1381  ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
# 1388  ['تركيب معدات التكييف والتدفئة والتهوية وصيانت...
# 1393  ['عد المبالغ المالية المتوافرة في آلة تسجيل ال...
# 1399  ['عد المبالغ المالية المتوافرة في آلة تسجيل ال...
# 1401  ['مساعدة البائعين وتقديم اقتراحات بأفضل طريقة ...
# 1409  ['دراسة القضية وتجهيز ملفها وجمع البينات الخطي...
# 1411  ['مساعدة العملاء والمنشآت في مختلف المسائل الق...
# 1421  ['المشاركة في تطوير الأهداف الرئيسية للإدارة ا...
# 1426  ['تقديم المشورة للعميل وتسريح الشعر وتصفيفه وت...
# 1432  ['عد المبالغ المالية المتوافرة في آلة تسجيل ال...
# 1436  ['دراسة وتحليل الحالة المرضية ووضع خطة وبرنامج...
# 1438  ['بيع مجموعة من السلع والخدمات للعملاء، وتوفير...
# 1444  ['الإشراف على مدخلي البيانات والتأكد من صحة ال...
# 1451  ['تفقد وتشغيل وخدمة معدات المختبر،أخذ عينات ال...
# 1467  ['دراسة التركيبات الدوائية للعقاقير والعلاجات ...
# 1468  ['تشغيل آلة تشطيب الرخام وابعادء الأجزاء المتف...
# 1469  ['دراسة التركيبات الدوائية للعقاقير والعلاجات ...
#
#                                               job_tasks  \
# 930   ['   تخطيط طريقة تنسيق المنتجات في مكان العرض،...
# 931   ['   دراسة مواصفات وتركيبات الادوية والعقاقير ...
# 947   ['   تقديم استشارات  لتطوير الأهداف الرئيسيةفي...
# 949   ['   اختيار إطار النظارة بالتنسيق مع صاحب العل...
# 952   ['   الحفاظ على قائمة الحجوزات، وتوفير السجلات...
# 961   ['   تحديد الأهداف العامة والفرعية للتسويق وتط...
# 975   ['تطوير الأهداف الرئيسية للشؤون الإدارية، وتطو...
# 1046  ['   الرد على الأسئلة والاستعلامات الأساسية لل...
# 1101  ['   تدقيق المطالبات المالية والتأكد من اكتمال...
# 1102  ['   تدقيق المطالبات المالية والتأكد من اكتمال...
# 1103  ['   تدقيق المطالبات المالية والتأكد من اكتمال...
# 1104  ['   تحديد المواد اللازمة ومواصفاتها وتقدير كم...
# 1105  ['   وضع التصاميم لمشاريع الإنشاءات الداخلية و...
# 1106  ['   وضع التصاميم لمشاريع الإنشاءات وإدارة فري...
# 1107  ['   أخذ المقاسات من الموقع أو من المخططات وال...
# 1108  ['   مساعدة مهنس الأبنية في إعداد خطة وبرنامج ...
# 1109  ['   استقبال القضية وتحديد نوعها وتحليل عناصره...
# 1120  ['   تدقيق المطالبات المالية والتأكد من اكتمال...
# 1135  ['   حفظ سجلات الموظفين، وتحديثها، وتسجيل البي...
# 1147  ['   استقبال الزوار والعملاء والترحيب بهم وتحد...
# 1154  ['   بيع مجموعة من السلع والخدمات للعملاء.', '...
# 1170  ['   استقبال الزوار والعملاء والترحيب بهم وتحد...
# 1190  [' الاعمال الادارية بين جهة الاشراف والمقاول و...
# 1242  ['   تطوير التطبيقات وقواعد البيانات من خلال ت...
# 1253  ['   الحفاظ على قائمة الحجوزات، وتوفير السجلات...
# 1259  ['   الحفاظ على قائمة الحجوزات، وتوفير السجلات...
# 1274  ['   الحفاظ على قائمة الحجوزات، وتوفير السجلات...
# 1294  ['   تقديم الدعم والمساعدة الفنية للموظفين وال...
# 1296  ['   المشاركة في تطوير الأهداف الرئيسية للشؤون...
# 1322  ['   المشاركة في وضع وإعداد الخطط والأهداف الخ...
# 1333  ['   تدقيق المطالبات المالية والتأكد من اكتمال...
# 1334  ['   تنظيم مواعيد المدير/الرئيس وتذكيره بها، و...
# 1347  ['   إعداد التصاميم والمخططات الكهربائية لمشار...
# 1381  ['   تدقيق المطالبات المالية والتأكد من اكتمال...
# 1388  ['   المساهمة في مجمل عملية تصميم نظم التهوية ...
# 1393  ['   عدّ المبالغ المالية وتسجيلها في آلة تسجيل...
# 1399  ['   عدّ المبالغ المالية وتسجيلها في آلة تسجيل...
# 1401  ['   تقييم رغبات العملاء والميزانيات المحددة و...
# 1409  ['   استقبال القضية وتحديد نوعها وتحليل عناصره...
# 1411  ['   تأهيل الطلبات وتقييم الخيارات القانونية، ...
# 1421  ['   المشاركة في تطوير الأهداف الرئيسية للإدار...
# 1426  ['   استقبال العميل وإجلاسه على كرسي القص  ووض...
# 1432  ['   عدّ المبالغ المالية وتسجيلها في آلة تسجيل...
# 1436  ['   دراسة وتحليل برنامج المعالجة الطبيعية الم...
# 1438  ['   بيع مجموعة من السلع والخدمات للعملاء.', '...
# 1444  ['   تدقيق البيانات بعد إدخالها، والتأكد من صح...
# 1451  ['   تفقد وتشغيل وخدمة معدات حفظ وفحص العينات ...
# 1467  ['   دراسة مواصفات وتركيبات الادوية والعقاقير ...
# 1468  ['   تسوية الرخام بواسطة أقراص الألماس الحديدي...
# 1469  ['   دراسة مواصفات وتركيبات الادوية والعقاقير ...
#
#                                               comp_name     comp_no  \
# 930    صيدليه السوسن الجديده لصاحبها سراج عمر سراج عابد     9-97451
# 931    صيدليه السوسن الجديده لصاحبها سراج عمر سراج عابد     9-97451
# 947                 برنامج مستشفى الملك فهدللحرس الوطني    EST-1237
# 949    شركة الدكتور حامد سليمان الاحمدي وشركاه المحدوده  10-1673172
# 952                                  فندق ظاظا الفندقية   9-2126602
# 961                     شركة رفا الطبية (شركة شخص واحد)    1-362446
# 975          شركة الرعاية الموثوقة الطبية شركة شخص واحد   1-2466520
# 1046                        شركة الخبير التربوي للتدريب  10-1967416
# 1101                  مؤسسة ساري الليل للمقاولات العامة  19-1951616
# 1102                        شركة أطياف للخدمات المساندة   1-1948186
# 1103                 مؤسسة فؤاد منصور فؤاد قطب التجارية    9-184502
# 1104                        مؤسسة اجواء اريحه للمقاولات     2-36018
# 1105                مؤسسة زرقاء اليمامة للتطوير العقاري   9-2018500
# 1106                مؤسسة زرقاء اليمامة للتطوير العقاري   9-2018500
# 1107                   مؤسسة مكعبات الإستثمار للمقاولات  13-1290630
# 1108  شركة الخدمات الاستشارية السعودية للاستشارات ال...   1-1264988
# 1109  راكان بن عويد الذيابي والبراء بن بهجت العمودي ...   9-2008040
# 1120                       شركة اتقان الصيانة للمقاولات   1-2628313
# 1135  الفلاح الراقي للوحدات السكنية المفروشة لصاحبته...    13-85391
# 1147                            معهد الجودة بلس للتدريب   9-2088192
# 1154                     أسواق المسارات الرائعة للتجارة  11-2011773
# 1170                  شركة رؤيتك المحدودة شركة شخص واحد   1-2066262
# 1190                     شركة الاداء المتوازن للمقاولات   1-2433558
# 1242               شركـة ايجاد التقنية لتقنية المعلومات   1-1148347
# 1253   شركة هادية عبداللطيف جميل لتجارة المواد الغذائية   9-1517934
# 1259                          فندق فيو الشاطيء الفندقية   4-1984109
# 1274           شقق احلى الايام للوحدات السكنية المفروشة   9-1114133
# 1294               شركة خالد آرت المحدودة شركة شخص واحد   4-1946208
# 1296            مكتب تصميم المشاريع للاستشارات الهندسية   4-1990473
# 1322                  شركة مجحد للالمنيوم شركة شخص واحد   8-1982771
# 1333                      مؤسسة الاتقان للتطوير العقاري   9-1682987
# 1334                      مؤسسة الاتقان للتطوير العقاري   9-1682987
# 1347                 مؤسسة صفوة الأيدي للمقاولات العامة   4-2013589
# 1381                       شركة اتقان الصيانة للمقاولات   1-2628313
# 1388                           مؤسسة جيل طيبة للمقاولات    10-77977
# 1393                            مغاسل نسيم الفل للملابس  15-1963098
# 1399                            مغاسل نسيم الفل للملابس  15-1963098
# 1401                                مؤسسة فانس العقارية   1-2268591
# 1409  شركة الخبراء المتحدون للمحاماة والاستشارات الق...   1-2334348
# 1411  شركة الخبراء المتحدون للمحاماة والاستشارات الق...   1-2334348
# 1421                شركة إرفاء المحدودة (شركة شخص واحد)  17-1989300
# 1426                   صالون تشرين ثاني للتزيين النسائي   1-2593881
# 1432                  مؤسسة التذوق الحلو لتقديم الوجبات   1-2559144
# 1436             مجمع ارجوان سامي بن نائف العتيبي الطبي   2-1949575
# 1438                مؤسسة ريان سعد عواد الدهام للحلويات   4-1971557
# 1444                          خالد عوض الجوهي للمقاولات   1-2073853
# 1451                         مجمع ابتسامة العائلة الطبي   1-2599562
# 1467                شركة تقنية الدواجن والألبان للتجارة   1-2415250
# 1468  مصنع عبدالرحمن بن محمد بن عبدالعزيز العبدالقاد...  15-1971895
# 1469                شركة تقنية الدواجن والألبان للتجارة   1-2415250
#
#        comp_type     comp_size eco_activity  \
# 930          خاص   صغيرة فئة ب          NaN
# 931          خاص   صغيرة فئة ب          NaN
# 947   شبه حكومية         كبيرة          NaN
# 949          خاص         كبيرة          NaN
# 952          خاص   صغيرة فئة أ          NaN
# 961          خاص   صغيرة فئة ب          NaN
# 975          خاص   صغيرة فئة ب          NaN
# 1046         خاص   صغيرة فئة ب          NaN
# 1101         خاص   صغيرة فئة ب          NaN
# 1102         خاص         كبيرة          NaN
# 1103         خاص   صغيرة فئة أ          NaN
# 1104         خاص   صغيرة فئة ب          NaN
# 1105         خاص   صغيرة فئة أ          NaN
# 1106         خاص   صغيرة فئة أ          NaN
# 1107         خاص   صغيرة فئة ب          NaN
# 1108         خاص         كبيرة          NaN
# 1109         خاص   صغيرة فئة ب          NaN
# 1120         خاص  متوسطة فئة ب          NaN
# 1135         خاص   صغيرة فئة ب          NaN
# 1147         خاص   صغيرة فئة أ          NaN
# 1154         خاص   صغيرة فئة ب          NaN
# 1170         خاص   صغيرة فئة ب          NaN
# 1190         خاص  متوسطة فئة ج          NaN
# 1242         خاص   صغيرة فئة ب          NaN
# 1253         خاص  متوسطة فئة أ          NaN
# 1259         خاص   صغيرة فئة ب          NaN
# 1274         خاص   صغيرة فئة ب          NaN
# 1294         خاص   صغيرة فئة ب          NaN
# 1296         خاص  مؤسسات صغيرة          NaN
# 1322         خاص   صغيرة فئة أ          NaN
# 1333         خاص   صغيرة فئة ب          NaN
# 1334         خاص   صغيرة فئة ب          NaN
# 1347         خاص   صغيرة فئة أ          NaN
# 1381         خاص  متوسطة فئة ب          NaN
# 1388         خاص  متوسطة فئة أ          NaN
# 1393         خاص  مؤسسات صغيرة          NaN
# 1399         خاص  مؤسسات صغيرة          NaN
# 1401         خاص  مؤسسات صغيرة          NaN
# 1409         خاص  مؤسسات صغيرة          NaN
# 1411         خاص  مؤسسات صغيرة          NaN
# 1421         خاص  مؤسسات صغيرة          NaN
# 1426         خاص  مؤسسات صغيرة          NaN
# 1432         خاص  مؤسسات صغيرة          NaN
# 1436         خاص  مؤسسات صغيرة          NaN
# 1438         خاص  مؤسسات صغيرة          NaN
# 1444         خاص  مؤسسات صغيرة          NaN
# 1451         خاص  مؤسسات صغيرة          NaN
# 1467         خاص   صغيرة فئة ب          NaN
# 1468         خاص   صغيرة فئة أ          NaN
# 1469         خاص   صغيرة فئة ب          NaN
#
#                                                  qualif           region  \
# 930                                       No requarment      مكة المكرمة
# 931   ['Skill data', 'التواصل', 'متوسط', 'الاتصال', ...      مكة المكرمة
# 947     ['Language data', 'اللغة الإنجليزية ', 'محترف']           الرياض
# 949   ['Skill data', 'العمل ضمن فريق', 'محترف', 'موا...  المدينة المنورة
# 952                                       No requarment      مكة المكرمة
# 961   ['Skill data', 'خبرة سابقة في التسويق الطبي', ...           الرياض
# 975   ['Skill data', 'Multitask Performance ', 'محتر...           الرياض
# 1046  ['Skill data', 'شخصية قوية وجذابة', 'محترف', '...  المدينة المنورة
# 1101                                      No requarment  المنطقة الشرقية
# 1102                                      No requarment           الرياض
# 1103                    ['Skill data', 'Language data']      مكة المكرمة
# 1104  ['Skill data', 'Language data', 'Professional ...           القصيم
# 1105                                      No requarment      مكة المكرمة
# 1106                                      No requarment      مكة المكرمة
# 1107                                      No requarment      مكة المكرمة
# 1108                                      No requarment           الرياض
# 1109  ['Skill data', 'مراجعة المحاكم والدوائر الحكوم...           الرياض
# 1120  ['Skill data', 'خبره في الضريبة', 'محترف', 'Pr...           الرياض
# 1135                                      No requarment      مكة المكرمة
# 1147  ['Skill data', 'مهارات التسويق - ', 'متوسط', '...      مكة المكرمة
# 1154                                      No requarment             عسير
# 1170  ['Skill data', 'الجرأه', 'محترف', 'Language da...           الرياض
# 1190  ['Skill data', 'خبرة فى تشغيل وصيانة محطات الص...  المدينة المنورة
# 1242  ['Skill data', 'ايجاده اللغة الانجليزية ', 'مت...            نجران
# 1253           ['Language data', 'الانجليزية', 'محترف']      مكة المكرمة
# 1259  ['Skill data', 'التعامل مع العملاء', 'متوسط', ...  المنطقة الشرقية
# 1274  ['Skill data', 'معرفة التعامل مع برنامج نزيل',...      مكة المكرمة
# 1294           ['Language data', 'الانجليزية', 'متوسط']  المنطقة الشرقية
# 1296                                      No requarment  المنطقة الشرقية
# 1322                                      No requarment  المنطقة الشرقية
# 1333  ['Skill data', 'متقن', 'متوسط', 'Language data...      مكة المكرمة
# 1334  ['Skill data', 'متقن', 'متوسط', 'Language data...      مكة المكرمة
# 1347            ['Language data', 'الانجليزي', 'متوسط']  المنطقة الشرقية
# 1381  ['Skill data', 'خبره في الضريبة', 'محترف', 'Pr...           الرياض
# 1388  ['Professional certificate \\ License data', '...  المدينة المنورة
# 1393                                      No requarment  المنطقة الشرقية
# 1399                                      No requarment           الرياض
# 1401  ['Skill data', 'عقاري', 'مبتدئ', 'Language dat...           الرياض
# 1409  ['Professional certificate \\ License data', '...           الرياض
# 1411  ['Skill data', 'إدارة وتنظيم المستندات والوثائ...           الرياض
# 1421                                      No requarment             حائل
# 1426                ['Skill data', 'صف الشعر', 'متوسط']           الرياض
# 1432                                      No requarment           الرياض
# 1436                                      No requarment           الرياض
# 1438  ['Language data', 'العربية', 'محترف', 'الانجلي...           الرياض
# 1444  ['Skill data', 'اتقان الحاسب ', 'متوسط', 'Lang...           الرياض
# 1451  ['Professional certificate \\ License data', '...           الرياض
# 1467  ['Professional certificate \\ License data', '...           الرياض
# 1468  ['Skill data', 'متقن للعمل وشغوف ويرغب بالتطور...  المنطقة الشرقية
# 1469  ['Professional certificate \\ License data', '...           الرياض
#
#               city                                           benefits  \
# 930      JEDDAH...           ['Salary', '4000.0', 'Benefits', '1000']
# 931      JEDDAH...           ['Salary', '7500.0', 'Benefits', '1500']
# 947   AR RIYADH...                              ['Salary', '15532.0']
# 949   AL MADINA...  ['Salary', '4667.0', 'Benefits', 'بدل انتقال= ...
# 952   ABU MARAG...                               ['Salary', '4082.0']
# 961   AR RIYADH...                               ['Salary', '5500.0']
# 975   AR RIYADH...  ['Salary', '12000.0', 'Benefits', 'تعتمد على ا...
# 1046  AL MADINA...                               ['Salary', '4000.0']
# 1101  HAFAR AL ...                               ['Salary', '4000.0']
# 1102  AR RIYADH...                               ['Salary', '6000.0']
# 1103     JEDDAH...  ['Salary', '6000.0', 'Benefits', '4500 ريال را...
# 1104    AL HAZM...        ['Salary', '3500.0', 'Benefits', 'لا يوجد']
# 1105     JEDDAH...          ['Salary', '8000.0', 'Benefits', 'حوافز']
# 1106     JEDDAH...          ['Salary', '7000.0', 'Benefits', 'حوافز']
# 1107  MAKKAH AL...                               ['Salary', '4000.0']
# 1108  AR RIYADH...  ['Salary', '5000.0', 'Benefits', 'تأمين طبي', ...
# 1109  AR RIYADH...  ['Salary', '5000.0', 'Benefits', 'يتغير الراتب...
# 1120  AR RIYADH...  ['Salary', '6000.0', 'Benefits', 'الراتب تقريب...
# 1135  MAKKAH AL...                               ['Salary', '3200.0']
# 1147     JEDDAH...                               ['Salary', '4000.0']
# 1154    MUHAYIL...   ['Salary', '3000.0', 'Benefits', 'عمولة مبيعات']
# 1170  ABA AL KI...                               ['Salary', '4500.0']
# 1190  AL MADINA...                               ['Salary', '7000.0']
# 1242  ABA AR RA...                              ['Salary', '10000.0']
# 1253     JEDDAH...                               ['Salary', '5500.0']
# 1259  AD DAMMAM...      ['Salary', '4000.0', 'Benefits', 'تأمينات  ']
# 1274     JEDDAH...                               ['Salary', '4000.0']
# 1294  AD DAMMAM...                               ['Salary', '4000.0']
# 1296  AD DAMMAM...                              ['Salary', '12400.0']
# 1322  AL MUBARR...                               ['Salary', '4000.0']
# 1333     JEDDAH...   ['Salary', '4000.0', 'Benefits', 'حسب المقابلة']
# 1334     JEDDAH...   ['Salary', '4000.0', 'Benefits', 'حسب المقابة ']
# 1347    DHAHRAN...  ['Salary', '7000.0', 'Benefits', 'تأمين صحي و ...
# 1381  AR RIYADH...  ['Salary', '6000.0', 'Benefits', 'الراتب تقريب...
# 1388  AL MADINA...                               ['Salary', '4000.0']
# 1393  AL KHUBAR...                               ['Salary', '4000.0']
# 1399  AL KHUBAR...                               ['Salary', '4000.0']
# 1401      RUMAH...                               ['Salary', '4000.0']
# 1409  AR RIYADH...                               ['Salary', '5000.0']
# 1411  AR RIYADH...                               ['Salary', '4000.0']
# 1421  ABA AL HI...                              ['Salary', '14000.0']
# 1426  AR RIYADH...                               ['Salary', '4000.0']
# 1432   AL BIYAD...                               ['Salary', '4000.0']
# 1436   AL KHARJ...                               ['Salary', '4000.0']
# 1438  AR RIYADH...                               ['Salary', '4500.0']
# 1444  HAFIRAT N...                               ['Salary', '4500.0']
# 1451  AR RIYADH...                               ['Salary', '5000.0']
# 1467  AR RIYADH...                               ['Salary', '7000.0']
# 1468  AL KHUBAR...  ['Salary', '4000.0', 'Benefits', 'اجازة سنوية ...
# 1469  AR RIYADH...                               ['Salary', '7000.0']
#
#        contract positions     job_post_id     exper gender
# 930   دوام كامل     0 / 2  20202026390782   0 Years      F
# 931   دوام كامل     0 / 2  20202026390776   0 Years      F
# 947   دوام كامل     0 / 1  20202026390144  10 Years   both
# 949   دوام كامل     0 / 5  20202026390106   0 Years   both
# 952   دوام كامل     0 / 1  20202026379628   0 Years      M
# 961   دوام كامل     0 / 1  20202026377722   2 Years      F
# 975   دوام كامل     0 / 1  20202026368280   4 Years   both
# 1046  دوام كامل     0 / 1  20202026367635   2 Years      F
# 1101  دوام كامل     0 / 1  20202026391571   0 Years      F
# 1102  دوام كامل     0 / 1  20202026391554   0 Years      F
# 1103  دوام كامل     0 / 1  20202026391499   4 Years      M
# 1104  دوام كامل     0 / 1  20202026391456   2 Years      M
# 1105  دوام كامل     0 / 1  20202026391452   2 Years   both
# 1106  دوام كامل     0 / 1  20202026391450   2 Years   both
# 1107  دوام كامل     0 / 2  20202026391426   2 Years   both
# 1108  دوام كامل     0 / 9  20202026391405   4 Years      M
# 1109  دوام كامل     0 / 1  20202026391401   4 Years      M
# 1120  دوام كامل     0 / 1  20202026391036   2 Years   both
# 1135  دوام كامل     0 / 1  20202026377493   0 Years   both
# 1147  دوام كامل     0 / 3  20202026375986   0 Years   both
# 1154  دوام كامل     0 / 2  20202026374445   0 Years   both
# 1170  دوام كامل     0 / 2  20202026355233   0 Years   both
# 1190  دوام كامل     0 / 1  20202026351183   7 Years      M
# 1242  دوام كامل     0 / 5  20202026398658   0 Years   both
# 1253  دوام كامل     0 / 2  20202026398214   2 Years   both
# 1259  دوام كامل     0 / 3  20202026396465   0 Years      M
# 1274  دوام كامل     0 / 1  20202026394783   0 Years      M
# 1294  دوام كامل     0 / 1  20202026404297   2 Years      M
# 1296  دوام كامل     0 / 1  20202026404052   7 Years      M
# 1322  دوام كامل     0 / 1  20202026401334   0 Years      F
# 1333  دوام كامل     0 / 2  20202026401054   0 Years   both
# 1334  دوام كامل     0 / 2  20202026400869   0 Years   both
# 1347  دوام كامل     0 / 1  20202026400078   0 Years      F
# 1381  دوام كامل     1 / 1  20202026391036   2 Years   both
# 1388  دوام كامل     0 / 1  20202026368859   2 Years      M
# 1393  دوام كامل     0 / 3  20202026407308   0 Years   both
# 1399  دوام كامل     0 / 2  20202026407112   0 Years   both
# 1401  دوام كامل     0 / 1  20202026407053   0 Years      F
# 1409  دوام كامل     0 / 2  20202026406912   2 Years   both
# 1411  دوام كامل     0 / 2  20202026406840   0 Years   both
# 1421  دوام كامل     0 / 1  20202026406695   7 Years   both
# 1426  دوام كامل     0 / 2  20202026406598   4 Years      F
# 1432  دوام كامل     0 / 2  20202026406120   0 Years      M
# 1436  دوام كامل     0 / 1  20202026405893   0 Years      F
# 1438  دوام كامل     0 / 2  20202026405668   2 Years      M
# 1444  دوام كامل     0 / 5  20202026405354   0 Years   both
# 1451  دوام كامل     0 / 2  20202026404173   0 Years   both
# 1467  دوام كامل     0 / 1  20202026399061   0 Years   both
# 1468  دوام كامل     0 / 3  20202026398972   0 Years      M
# 1469  دوام كامل     0 / 1  20202026399061   0 Years   both

# %%
#handle null values with company name
df['eco_activity'] = df.apply(lambda x: x['comp_name'] if pd.isna(x['eco_activity']) else x['eco_activity'], axis=1)

# %%
df[df['eco_activity'].isna()]
# Out:
# Empty DataFrame
# Columns: [job_title, job_date, job_desc, job_tasks, comp_name, comp_no, comp_type, comp_size, eco_activity, qualif, region, city, benefits, contract, positions, job_post_id, exper, gender]
# Index: []

# %%
df
# Out:
#                       job_title    job_date  \
# 0                         محاسب  27/05/1444
# 1                          بائع  27/05/1444
# 2     أخصائي عمليات موارد بشرية  27/05/1444
# 3               ميكانيكي سيارات  27/05/1444
# 4                         محاسب  27/05/1444
# ...                         ...         ...
# 1465        مهندس تقنية معلومات  19/06/1444
# 1466                     سكرتير  19/06/1444
# 1467                      صيدلي  18/06/1444
# 1468        مشغل آلة تشطيب رخام  18/06/1444
# 1469                      صيدلي  18/06/1444
#
#                                                job_desc  \
# 0     ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
# 1     ['بيع مجموعة من السلع والخدمات للعملاء، وتوفير...
# 2     ['تنفيذ الإجراءات والأنظمة والنماذج الخاصة بمر...
# 3     ['تشخيص أعطال السيارات وإصلاحها وتنفيذ برامج ا...
# 4     ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
# ...                                                 ...
# 1465  ['دراسة احتياجات العميل من الأجهزة الحاسوبية و...
# 1466  ['دعم المدير أو الإدارة من خلال كتابة الوثائق ...
# 1467  ['دراسة التركيبات الدوائية للعقاقير والعلاجات ...
# 1468  ['تشغيل آلة تشطيب الرخام وابعادء الأجزاء المتف...
# 1469  ['دراسة التركيبات الدوائية للعقاقير والعلاجات ...
#
#                                               job_tasks  \
# 0     ['   تدقيق المطالبات المالية والتأكد من اكتمال...
# 1     ['   بيع مجموعة من السلع والخدمات للعملاء.', '...
# 2     ['   تنفيذ الإجراءات والأنظمة والنماذج الخاصة ...
# 3     ['   فحص أداء المعدّات الكهربائية والميكانيكية...
# 4     ['   تدقيق المطالبات المالية والتأكد من اكتمال...
# ...                                                 ...
# 1465  ['   متابعة وتقييم عملية جمع وتحليل المعطيات و...
# 1466  ['   تدوين الملاحظات، التي يتم إملاؤها، بطريقة...
# 1467  ['   دراسة مواصفات وتركيبات الادوية والعقاقير ...
# 1468  ['   تسوية الرخام بواسطة أقراص الألماس الحديدي...
# 1469  ['   دراسة مواصفات وتركيبات الادوية والعقاقير ...
#
#                                               comp_name     comp_no comp_type  \
# 0                              شركة مقر العالم للسفريات    1-317262       خاص
# 1                          شركة عالم الكهرباء للمقاولات   4-1324428       خاص
# 2                                       شركه دار السلام    1-155294       خاص
# 3                               مؤسسة لمكو لغيار الزيوت   8-1925495       خاص
# 4                          مؤسسة فكرة اليمامة للمقاولات   1-2356639       خاص
# ...                                                 ...         ...       ...
# 1465                  مطعم الاوراق الخضر لتقديم الوجبات  15-1698448       خاص
# 1466         شركة ملتقى التجار لحاضنات و مسرعات الأعمال   9-2013930       خاص
# 1467                شركة تقنية الدواجن والألبان للتجارة   1-2415250       خاص
# 1468  مصنع عبدالرحمن بن محمد بن عبدالعزيز العبدالقاد...  15-1971895       خاص
# 1469                شركة تقنية الدواجن والألبان للتجارة   1-2415250       خاص
#
#          comp_size                                       eco_activity  \
# 0     متوسطة فئة أ                        أنشطة وكالات السياحة والسفر
# 1     متوسطة فئة ب  تركيب انظمة التبريد وتكييف الهواء وصيانتها واص...
# 2     متوسطة فئة أ               ترميمات المباني السكنية والغير سكنية
# 3      صغيرة فئة ب                            مؤسسة لمكو لغيار الزيوت
# 4            كبيرة                   الإنشاءات العامة للمباني السكنية
# ...            ...                                                ...
# 1465   صغيرة فئة ب                                  المطاعم مع الخدمة
# 1466   صغيرة فئة ب                       أنشطة حاضنات ومسرعات الأعمال
# 1467   صغيرة فئة ب                شركة تقنية الدواجن والألبان للتجارة
# 1468   صغيرة فئة أ  مصنع عبدالرحمن بن محمد بن عبدالعزيز العبدالقاد...
# 1469   صغيرة فئة ب                شركة تقنية الدواجن والألبان للتجارة
#
#                                                  qualif           region  \
# 0        ['Language data', 'اللغة الانجليزية', 'محترف']           الرياض
# 1                                         No requarment  المنطقة الشرقية
# 2              ['Language data', 'الانجليزيه', 'محترف']           الرياض
# 3     ['Skill data', 'صيانة السيارات وتقييم الاعطال'...  المنطقة الشرقية
# 4     ['Skill data', 'تحمل ضغط العمل', 'محترف', 'Lan...           الرياض
# ...                                                 ...              ...
# 1465                                      No requarment           الرياض
# 1466  ['Skill data', 'فن التواصل', 'محترف', 'Languag...      مكة المكرمة
# 1467  ['Professional certificate \\ License data', '...           الرياض
# 1468  ['Skill data', 'متقن للعمل وشغوف ويرغب بالتطور...  المنطقة الشرقية
# 1469  ['Professional certificate \\ License data', '...           الرياض
#
#               city                                           benefits  \
# 0     AR RIYADH...                               ['Salary', '5000.0']
# 1     AD DAMMAM...                               ['Salary', '5000.0']
# 2     ATH THUMA...                               ['Salary', '4000.0']
# 3      AL HUFUF...                               ['Salary', '5000.0']
# 4     AR RIYADH...                               ['Salary', '5000.0']
# ...            ...                                                ...
# 1465  AR RIYADH...                               ['Salary', '5500.0']
# 1466     JEDDAH...                               ['Salary', '4000.0']
# 1467  AR RIYADH...                               ['Salary', '7000.0']
# 1468  AL KHUBAR...  ['Salary', '4000.0', 'Benefits', 'اجازة سنوية ...
# 1469  AR RIYADH...                               ['Salary', '7000.0']
#
#        contract positions     job_post_id    exper gender
# 0     دوام كامل     0 / 1  20202026350419  0 Years   both
# 1     دوام كامل     0 / 3  20202026350389  0 Years   both
# 2     دوام كامل     0 / 2  20202026350347  2 Years   both
# 3     دوام كامل    0 / 10  20202026350219  0 Years      M
# 4     دوام كامل     0 / 1  20202026350043  0 Years   both
# ...         ...       ...             ...      ...    ...
# 1465  دوام كامل     0 / 1  20202026400353  0 Years   both
# 1466  دوام كامل     0 / 1  20202026399849  2 Years   both
# 1467  دوام كامل     0 / 1  20202026399061  0 Years   both
# 1468  دوام كامل     0 / 3  20202026398972  0 Years      M
# 1469  دوام كامل     0 / 1  20202026399061  0 Years   both
#
# [1470 rows x 18 columns]

# %%
df.isna().sum()
# Out:
# job_title       0
# job_date        0
# job_desc        0
# job_tasks       0
# comp_name       0
# comp_no         0
# comp_type       0
# comp_size       0
# eco_activity    0
# qualif          0
# region          0
# city            0
# benefits        0
# contract        0
# positions       0
# job_post_id     0
# exper           0
# gender          0
# dtype: int64

# %%
# go back to 6th dimention --> Completeness

# %% [markdown]
# ### Correcting errors
#
# -------------------

# %%
df.dtypes
# Out:
# job_title       object
# job_date        object
# job_desc        object
# job_tasks       object
# comp_name       object
# comp_no         object
# comp_type       object
# comp_size       object
# eco_activity    object
# qualif          object
# region          object
# city            object
# benefits        object
# contract        object
# positions       object
# job_post_id      int64
# exper           object
# gender          object
# dtype: object

# %%
df['exper'] = df['exper'].map(lambda x: x.split('Y')[0])
df['exper'] = df['exper'].astype(int)

# %%
df['positions'] = df['positions'].map(lambda x: x.split('/')[1])

# %%
df['positions'] = df['positions'].astype(int)

# %%
df.dtypes
# Out:
# job_title       object
# job_date        object
# job_desc        object
# job_tasks       object
# comp_name       object
# comp_no         object
# comp_type       object
# comp_size       object
# eco_activity    object
# qualif          object
# region          object
# city            object
# benefits        object
# contract        object
# positions        int32
# job_post_id      int64
# exper            int32
# gender          object
# dtype: object

# %%
df['benefits']
# Out:
# 0                                    ['Salary', '5000.0']
# 1                                    ['Salary', '5000.0']
# 2                                    ['Salary', '4000.0']
# 3                                    ['Salary', '5000.0']
# 4                                    ['Salary', '5000.0']
#                               ...
# 1465                                 ['Salary', '5500.0']
# 1466                                 ['Salary', '4000.0']
# 1467                                 ['Salary', '7000.0']
# 1468    ['Salary', '4000.0', 'Benefits', 'اجازة سنوية ...
# 1469                                 ['Salary', '7000.0']
# Name: benefits, Length: 1470, dtype: object

# %%
df['Salary'] = df['benefits'].map(lambda x: x.split(',')[1])

# %%
df['Salary'] = df['Salary'].map(lambda x: x.split(']')[0])

# %%
df['Salary']
# Out:
# 0        '5000.0'
# 1        '5000.0'
# 2        '4000.0'
# 3        '5000.0'
# 4        '5000.0'
#           ...
# 1465     '5500.0'
# 1466     '4000.0'
# 1467     '7000.0'
# 1468     '4000.0'
# 1469     '7000.0'
# Name: Salary, Length: 1470, dtype: object

# %%
df['Salary'] = df['Salary'].str.replace("'", "", regex=False) 
df['Salary'] = df['Salary'].str.strip()  
df['Salary'] = df['Salary'].astype(float)

# %%
df['Salary']
# Out:
# 0       5000.0
# 1       5000.0
# 2       4000.0
# 3       5000.0
# 4       5000.0
#          ...
# 1465    5500.0
# 1466    4000.0
# 1467    7000.0
# 1468    4000.0
# 1469    7000.0
# Name: Salary, Length: 1470, dtype: float64

# %%
df['gender'] = df['gender'].str.replace("M", "Male", regex=False)

# %%
df['gender'] = df['gender'].str.replace("F", "Female", regex=False)

# %%
df['gender'] = df['gender'].str.replace("both", "Both", regex=False)

# %%
df.head(50)
# Out:
#                          job_title    job_date  \
# 0                            محاسب  27/05/1444
# 1                             بائع  27/05/1444
# 2        أخصائي عمليات موارد بشرية  27/05/1444
# 3                  ميكانيكي سيارات  27/05/1444
# 4                            محاسب  27/05/1444
# 5              مراقب كاميرات أمنية  27/05/1444
# 6                    سكرتير تنفيذي  27/05/1444
# 7                        مدير مكتب  27/05/1444
# 8              أخصائي إدارة مشاريع  27/05/1444
# 9                      مصمم جرافيك  26/05/1444
# 10               أخصائي ذكاء أعمال  26/05/1444
# 11                            بائع  26/05/1444
# 12                     محلل بيانات  26/05/1444
# 13                  مدير حساب عميل  26/05/1444
# 14                     مصمم جرافيك  26/05/1444
# 15                     مدخل بيانات  26/05/1444
# 16                      مطور برامج  26/05/1444
# 17               أخصائي إدارة اداء  26/05/1444
# 18                     مدخل بيانات  26/05/1444
# 19                         كيميائي  26/05/1444
# 20                           محاسب  26/05/1444
# 21                     مهندس زراعي  26/05/1444
# 22                           محاسب  26/05/1444
# 23              محلل نظم المعلومات  26/05/1444
# 24                           محاسب  26/05/1444
# 25                        مدير عام  26/05/1444
# 26                     مساعد إداري  26/05/1444
# 27              كاتب علاقات حكومية  26/05/1444
# 28                   سكرتير تنفيذي  26/05/1444
# 29                    مندوب مبيعات  26/05/1444
# 30                     مساعد إداري  25/05/1444
# 31                      معلم حضانة  25/05/1444
# 32                     فني كيميائي  25/05/1444
# 33                   مهندس كهربائي  25/05/1444
# 34                  مهندس ميكانيكي  25/05/1444
# 35                      مدير إداري  25/05/1444
# 36             فني هندسة ميكانيكية  25/05/1444
# 37              فني هندسة كهربائية  25/05/1444
# 38                     مدخل بيانات  25/05/1444
# 39                           محاسب  25/05/1444
# 40                        مدير فرع  25/05/1444
# 41                            بائع  25/05/1444
# 42               موظف استقبال فندق  25/05/1444
# 43                    مندوب مبيعات  25/05/1444
# 44                    أخصائي تسويق  25/05/1444
# 45  كاتب استعلامات مركز خدمة عملاء  25/05/1444
# 46                            بائع  25/05/1444
# 47                            بائع  25/05/1444
# 48                            بائع  25/05/1444
# 49       أخصائي عمليات موارد بشرية  25/05/1444
#
#                                              job_desc  \
# 0   ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
# 1   ['بيع مجموعة من السلع والخدمات للعملاء، وتوفير...
# 2   ['تنفيذ الإجراءات والأنظمة والنماذج الخاصة بمر...
# 3   ['تشخيص أعطال السيارات وإصلاحها وتنفيذ برامج ا...
# 4   ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
# 5   ['الإشراف على عمليات كاميرات المراقبة الأمنية،...
# 6   ['تنظيم المواعيد وإعداد المذكرات وإجراء المراس...
# 7   ['الإشراف المباشرعلى أنشطة إدارة وتخطيط وتنظيم...
# 8   ['تحليل عناصر وفعاليات المشروع ووضع الخطط والب...
# 9   ['تطوير الأفكار الإبداعية والمفاهيم لتوصيل الر...
# 10  ['تحديد مصادر المعلومات والبيانات اللازمة لإعد...
# 11  ['بيع مجموعة من السلع والخدمات للعملاء، وتوفير...
# 12  ['جمع  البيانات ومعالجتها وتقديمها في مجموعة م...
# 13  ['إدارة محفظة من حسابات العملاء المهمين، والحف...
# 14  ['لديه الخبرة   في اخراج العروض التقديمية الرس...
# 15        ['التمكن من استخدام برامج مايكروسفت أوفيس']
# 16  [' تحليل  وادارة تطبيقات باستخدام الأدوات البر...
# 17  [' فهم مبادئ الإدارة الإستراتيجية وقياس الأداء...
# 18  ['مراجعة استمارات البيانات وتدقيقها، وإدخال وت...
# 19  ['إجراء الأبحاث والتحاليل الكيميائية للعناصر و...
# 20  ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
# 21  ['دراسة خصائص ومكونات الأراضي والتربة الزراعية...
# 22  ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
# 23  ['جمع متطلبات العميل واحتياجاته، وإجراء المقاب...
# 24  ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
# 25  ['المشاركة في وضع الأهداف العامة والسياسات وال...
# 26  ['متابعة تنفيذ القرارات الادارية الصادرة عن ال...
# 27  ['توفير المعلومات اللازمة للتخليص على المعاملا...
# 28  ['تنظيم المواعيد وإعداد المذكرات وإجراء المراس...
# 29  ['جمع البيانات والمواصفات المتعلقة بالمنتجات (...
# 30  ['متابعة تنفيذ القرارات الادارية الصادرة عن ال...
# 31  ['وضع خطة أنشطة الحضانة وتزين الفصل بالرسومات ...
# 32  ['تركيب وتشغيل وتنفيذ برامج الصيانة الوقائية ل...
# 33  ['إعداد التصاميم والمخططات الكهربائية لمشاريع ...
# 34  ['إعداد التصاميم والمخططات لمشاريع وأعمال الهن...
# 35  ['المشاركة في تطوير الأهداف الرئيسية للشؤون ال...
# 36  ['المساعدة في أبحاث الهندسة الميكانيكية وتصميم...
# 37  ['تركيب المحركات واللوحات والمولدات والمحولات ...
# 38  ['مراجعة استمارات البيانات وتدقيقها، وإدخال وت...
# 39  ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
# 40  ['المشاركة في وضع وإعداد أهداف الفرع في ضوء تو...
# 41  ['بيع مجموعة من السلع والخدمات للعملاء، وتوفير...
# 42  ['الإشراف على خدمات الضيوف في مكتب الاستقبال، ...
# 43  ['جمع البيانات والمواصفات المتعلقة بالمنتجات (...
# 44  ['تحديد الأهداف وتطوير السياسات التسويقية للسل...
# 45  ['تقديم المشورة والمعلومات الأساسية للعملاء، و...
# 46  ['بيع مجموعة من السلع والخدمات للعملاء، وتوفير...
# 47  ['بيع مجموعة من السلع والخدمات للعملاء، وتوفير...
# 48  ['بيع مجموعة من السلع والخدمات للعملاء، وتوفير...
# 49  ['تنفيذ الإجراءات والأنظمة والنماذج الخاصة بمر...
#
#                                             job_tasks  \
# 0   ['   تدقيق المطالبات المالية والتأكد من اكتمال...
# 1   ['   بيع مجموعة من السلع والخدمات للعملاء.', '...
# 2   ['   تنفيذ الإجراءات والأنظمة والنماذج الخاصة ...
# 3   ['   فحص أداء المعدّات الكهربائية والميكانيكية...
# 4   ['   تدقيق المطالبات المالية والتأكد من اكتمال...
# 5   ['   الإشراف على عمليات كاميرات المراقبة، والت...
# 6   ['   تنظيم مواعيد المدير/الرئيس وتذكيره بها، و...
# 7   ['   إدارة وتوجيه عمليات وإجراءات تنسيق اجتماع...
# 8   ['   تحليل عناصر وفعاليات المشروع وارتباطها وت...
# 9   ['   التنسيق مع مالك التصميم (عملاء محليون أو ...
# 10  ['   دراسة وتحليل الخطط المعدة وتفصيلها إلى عم...
# 11  ['   بيع مجموعة من السلع والخدمات للعملاء.', '...
# 12  ['   جمع قواعد البيانات ومراجعتها وتنظيفها وإد...
# 13  ['   بناء علاقات مع كبار العملاء والمحافظة علي...
# 14  ['لديه الخبرة   في اخراج العروض التقديمية الرس...
# 15        ['التمكن من استخدام برامج مايكروسفت أوفيس']
# 16  ['   تحليل  وادارة تطبيقات باستخدام الأدوات ال...
# 17  [' فهم مبادئ الإدارة الإستراتيجية وقياس الأداء...
# 18  ['   مراجعة الاستمارات المتعلقة بالبيانات وترم...
# 19  ['   إجراء الأبحاث والتجارب والتحاليل الكمية و...
# 20  ['   تدقيق المطالبات المالية والتأكد من اكتمال...
# 21  ['   دراسة خصائص التربة الزراعية الفيزيائية وا...
# 22  ['   تدقيق المطالبات المالية والتأكد من اكتمال...
# 23  ['   جمع متطلبات العميل واحتياجاته، وإجراء الم...
# 24  ['   تدقيق المطالبات المالية والتأكد من اكتمال...
# 25  ['   المشاركة في وضع الأهداف والسياسات والمباد...
# 26  ['   تنفيذ التعليمات الادارية الصادرة عن الرئي...
# 27  ['   جمع البيانات والمعلومات عن  الوثائق والمس...
# 28  ['   تنظيم مواعيد المدير/الرئيس وتذكيره بها، و...
# 29  ['   بناء قاعدة بينات للعملاء الحاليين والمرتق...
# 30  ['   تنفيذ التعليمات الادارية الصادرة عن الرئي...
# 31  ['   وضع خطة أنشطة الحضانة وتزين الفصل بالرسوم...
# 32  ['   تركيب أجهزة المختبر الكيميائي بحسب المخطط...
# 33  ['   إعداد التصاميم والمخططات الكهربائية لمشار...
# 34  ['   إعداد التصاميم والمخططات لمشاريع أعمال ال...
# 35  ['   المشاركة في تطوير الأهداف الرئيسية للشؤون...
# 36  ['   المساعدة في وضع نظريات جديدة وتحسين الأسا...
# 37  ['   تحديد المخطط، وكمية المواد والمعدات واليد...
# 38  ['   مراجعة الاستمارات المتعلقة بالبيانات وترم...
# 39  ['   تدقيق المطالبات المالية والتأكد من اكتمال...
# 40  ['   المشاركة في وضع وإعداد الخطط والأهداف الخ...
# 41  ['   بيع مجموعة من السلع والخدمات للعملاء.', '...
# 42  ['   الحفاظ على قائمة الحجوزات، وتوفير السجلات...
# 43  ['   بناء قاعدة بينات للعملاء الحاليين والمرتق...
# 44  ['   تحديد الأهداف العامة والفرعية للتسويق وتط...
# 45  ['   الرد على الأسئلة والاستعلامات الأساسية لل...
# 46  ['   بيع مجموعة من السلع والخدمات للعملاء.', '...
# 47  ['1- إستقبال الزبائن وعمل أوامر الطلبات ', '2-...
# 48  ['   بيع مجموعة من السلع والخدمات للعملاء.', '...
# 49  ['   تنفيذ الإجراءات والأنظمة والنماذج الخاصة ...
#
#                                             comp_name     comp_no comp_type  \
# 0                            شركة مقر العالم للسفريات    1-317262       خاص
# 1                        شركة عالم الكهرباء للمقاولات   4-1324428       خاص
# 2                                     شركه دار السلام    1-155294       خاص
# 3                             مؤسسة لمكو لغيار الزيوت   8-1925495       خاص
# 4                        مؤسسة فكرة اليمامة للمقاولات   1-2356639       خاص
# 5                 مطاعم تراث الدمشقية للوجبات السريعة   1-1527188       خاص
# 6   شركة بيانات و دعم القرار للاستشارات في مجال ال...   9-2027654       خاص
# 7   شركة بيانات و دعم القرار للاستشارات في مجال ال...   9-2027654       خاص
# 8   شركة بيانات و دعم القرار للاستشارات في مجال ال...   9-2027654       خاص
# 9   شركة بيانات و دعم القرار للاستشارات في مجال ال...   9-2027654       خاص
# 10  شركة بيانات و دعم القرار للاستشارات في مجال ال...   9-2027654       خاص
# 11                 شركة بيت قطن للتجارة شركة شخص واحد   1-2397423       خاص
# 12  شركة بيانات و دعم القرار للاستشارات في مجال ال...   9-2027654       خاص
# 13                   مؤسسة عبر السوق لتقنية المعلومات   9-2046127       خاص
# 14                    مكتب مدارات للاستشارات الهندسية   3-1971776       خاص
# 15                    مكتب مدارات للاستشارات الهندسية   3-1971776       خاص
# 16                    مكتب مدارات للاستشارات الهندسية   3-1971776       خاص
# 17                    مكتب مدارات للاستشارات الهندسية   3-1971776       خاص
# 18                 شركة إرتقاء المتحدة لاجهزة السلامة   9-2117904       خاص
# 19                        شركة الغدير الدوليه للتسويق  13-1946886       خاص
# 20  شركة الصخرة المشرفة والسارية الخضراء للاستشارا...    1-321449       خاص
# 21    شركة الحبيب للتجارة والتعهدات التجارية المحدودة    9-170461       خاص
# 22                                  شركة خدمات للوقود   1-2222975       خاص
# 23    شركة الذهبيه الهندسيه للمقاولات (شركة شخص واحد)   1-2089504       خاص
# 24                         مؤسسة سلاسل بابل للمقاولات    13-97350       خاص
# 25              ورشة اضواء المشاعل للحدادة والالمنيوم  10-2010602       خاص
# 26                     مؤسسة اتجاهات النجاح للمقاولات   1-1118487       خاص
# 27   شركة عبدالرؤف عبدالوهاب العيد للاستشارات المهنية   1-2420217       خاص
# 28                  شركة كاف الرقمية للدعاية والاعلان   1-2421924       خاص
# 29      شركة صندوق الرقمي للاتصالات و تقنية المعلومات   1-2404398       خاص
# 30  مركز شذى محمد بن حمد الكثيري ضيافة الأطفال الأ...   1-2254620       خاص
# 31  مركز شذى محمد بن حمد الكثيري ضيافة الأطفال الأ...   1-2254620       خاص
# 32                       مصنع الاعشاب الشرقية للصناعة   6-1958652       خاص
# 33  شركة مصنع وائل حسن فارسي للغازات الصناعية شركة...  10-2012715       خاص
# 34  شركة مصنع وائل حسن فارسي للغازات الصناعية شركة...  10-2012715       خاص
# 35  شركة مصنع وائل حسن فارسي للغازات الصناعية شركة...  10-2012715       خاص
# 36  شركة مصنع وائل حسن فارسي للغازات الصناعية شركة...  10-2012715       خاص
# 37  شركة مصنع وائل حسن فارسي للغازات الصناعية شركة...  10-2012715       خاص
# 38        مؤسسة سلطان عبدالله صويلح المطيرى للمقاولات  14-1953483       خاص
# 39                          حلاق ديوان الدانه للحلاقة   4-2002778       خاص
# 40                                  شركة الزي للتجارة   9-2079452       خاص
# 41                    مجمع الرائعه الاقتصاديه التجاري  20-1958829       خاص
# 42                           فندق قصر الواحة الفندقية   1-2440535       خاص
# 43                       شركـة مجموعة المساع المحدودة   9-1386554       خاص
# 44                 شركة مصدر الحياة للصناعات الغذائية    1-203353       خاص
# 45                                        شركة الرهدن   4-2009325       خاص
# 46                          شركة متاجر رمانة التجارية   1-2082101       خاص
# 47              شركة مطعم بيت الشاورما لتقديم الوجبات   1-2239765       خاص
# 48                          شركة أطياب غناتي التجارية  29-1959880       خاص
# 49  شركة الصخرة المشرفة والسارية الخضراء للاستشارا...    1-321449       خاص
#
#        comp_size                                       eco_activity  \
# 0   متوسطة فئة أ                        أنشطة وكالات السياحة والسفر
# 1   متوسطة فئة ب  تركيب انظمة التبريد وتكييف الهواء وصيانتها واص...
# 2   متوسطة فئة أ               ترميمات المباني السكنية والغير سكنية
# 3    صغيرة فئة ب                            مؤسسة لمكو لغيار الزيوت
# 4          كبيرة                   الإنشاءات العامة للمباني السكنية
# 5    صغيرة فئة ب  تشغيل المقاصف والكفتيريات على أساس إمتياز محدد...
# 6    صغيرة فئة أ  إعادة تأهيل وهيكلة العمليات الإدارية والمالية ...
# 7    صغيرة فئة أ  إعادة تأهيل وهيكلة العمليات الإدارية والمالية ...
# 8    صغيرة فئة أ  إعادة تأهيل وهيكلة العمليات الإدارية والمالية ...
# 9    صغيرة فئة أ  إعادة تأهيل وهيكلة العمليات الإدارية والمالية ...
# 10   صغيرة فئة أ  إعادة تأهيل وهيكلة العمليات الإدارية والمالية ...
# 11  متوسطة فئة أ                     البيع بالجملة للملابس الرياضية
# 12   صغيرة فئة أ  إعادة تأهيل وهيكلة العمليات الإدارية والمالية ...
# 13   صغيرة فئة أ                تقديم خدمات تسويقية نيابةً عن الغير
# 14  متوسطة فئة ب                           إدارة المشاريع الانشائية
# 15  متوسطة فئة ب                           إدارة المشاريع الانشائية
# 16  متوسطة فئة ب                           إدارة المشاريع الانشائية
# 17  متوسطة فئة ب                           إدارة المشاريع الانشائية
# 18   صغيرة فئة أ        تركيب وصيانة أجهزة ومعدات الإنذار من الحريق
# 19   صغيرة فئة أ                    البيع بالجملة للمواد الكيميائية
# 20  متوسطة فئة ب               أنشطة الاستشارات الهندسية والمعمارية
# 21        عملاقة                         خدمات جمع النفايات البلدية
# 22   صغيرة فئة ب  البيع بالتجزئة لمعدات محطات الوقود وقطع غيارها...
# 23  متوسطة فئة ج  إنشاء وإقامة محطات وأبراج الاتصالات السلكية وا...
# 24   صغيرة فئة ب               ترميمات المباني السكنية والغير سكنية
# 25   صغيرة فئة أ              ورشة اضواء المشاعل للحدادة والالمنيوم
# 26   صغيرة فئة ب                   الإنشاءات العامة للمباني السكنية
# 27   صغيرة فئة أ                              أنشطة المكاتب الرئيسة
# 28   صغيرة فئة أ                تقديم خدمات تسويقية نيابةً عن الغير
# 29   صغيرة فئة ب           أنشطة الخدمات الإدارية المتكاملة للمكاتب
# 30   صغيرة فئة ب                        مراكز ضيافة الأطفال الأهلية
# 31   صغيرة فئة ب                        مراكز ضيافة الأطفال الأهلية
# 32   صغيرة فئة أ                خلط وتعبئة العطور والزيوت والنباتات
# 33   صغيرة فئة أ  انتاج الغازات الأولية ، يشمل ( الاوكسجين والهي...
# 34   صغيرة فئة أ  انتاج الغازات الأولية ، يشمل ( الاوكسجين والهي...
# 35   صغيرة فئة أ  انتاج الغازات الأولية ، يشمل ( الاوكسجين والهي...
# 36   صغيرة فئة أ  انتاج الغازات الأولية ، يشمل ( الاوكسجين والهي...
# 37   صغيرة فئة أ  انتاج الغازات الأولية ، يشمل ( الاوكسجين والهي...
# 38   صغيرة فئة ب  إصلاح وصيانة المحطات والشبكات والخطوط الرئيسية...
# 39   صغيرة فئة أ                                 الصالونات الرجالية
# 40  متوسطة فئة أ                                  شركة الزي للتجارة
# 41   صغيرة فئة أ                            مجمعات تجارية استهلاكية
# 42   صغيرة فئة ب                           فندق قصر الواحة الفندقية
# 43   صغيرة فئة أ        البيع بالتجزئة للمولدات الكهربائية ولوازمها
# 44         كبيرة         صناعة الخبز ومنتجاته بواسطة المخابز الآلية
# 45         كبيرة  غسل وكي والتنظيف الجاف لشتى أنواع الملابس بما ...
# 46  متوسطة فئة أ         بيع المشروبات بالتجزئة في المتاجر المتخصصة
# 47  متوسطة فئة ج              شركة مطعم بيت الشاورما لتقديم الوجبات
# 48   صغيرة فئة ب                          شركة أطياب غناتي التجارية
# 49  متوسطة فئة ب  شركة الصخرة المشرفة والسارية الخضراء للاستشارا...
#
#                                                qualif           region  \
# 0      ['Language data', 'اللغة الانجليزية', 'محترف']           الرياض
# 1                                       No requarment  المنطقة الشرقية
# 2            ['Language data', 'الانجليزيه', 'محترف']           الرياض
# 3   ['Skill data', 'صيانة السيارات وتقييم الاعطال'...  المنطقة الشرقية
# 4   ['Skill data', 'تحمل ضغط العمل', 'محترف', 'Lan...           الرياض
# 5   ['Skill data', 'اجادة الحاسب والتقنية ', 'متوس...           الرياض
# 6          ['Language data', 'لغة انجليزية', 'محترف']           الرياض
# 7          ['Language data', 'لغة انجليزية', 'محترف']           الرياض
# 8   ['Language data', 'لغة انجليزية', 'محترف', 'Pr...           الرياض
# 9          ['Language data', 'لغة انجليزية', 'متوسط']           الرياض
# 10         ['Language data', 'لغة انجليزية', 'متوسط']           الرياض
# 11                   ['Skill data', 'تسويق', 'مبتدئ']  المنطقة الشرقية
# 12             ['Language data', 'انجليزية', 'متوسط']           الرياض
# 13  ['Skill data', 'التسويق', 'مبتدئ', 'كتابة المح...      مكة المكرمة
# 14                                      No requarment             حائل
# 15                                      No requarment             حائل
# 16                                      No requarment             حائل
# 17                                      No requarment             حائل
# 18                                      No requarment      مكة المكرمة
# 19  ['Language data', 'الانجليزي ', 'متوسط', 'Prof...      مكة المكرمة
# 20           ['Language data', 'الانجليزية', 'متوسط']           الرياض
# 21  ['Professional certificate \\ License data', '...      مكة المكرمة
# 22      ['Skill data', 'التعامل مع الحاسب ', 'متوسط']           الرياض
# 23                                      No requarment           الرياض
# 24  ['Skill data', 'الحاسب', 'محترف', 'Language da...      مكة المكرمة
# 25  ['Skill data', 'حداد', 'متوسط', 'Language data...  المدينة المنورة
# 26          ['Language data', 'الإنجليزية ', 'محترف']           الرياض
# 27                                      No requarment           الرياض
# 28  ['Skill data', 'صياغة التقارير بلغة عربية واضح...           الرياض
# 29              ['Language data', 'انجليزي', 'متوسط']           الرياض
# 30                                      No requarment           الرياض
# 31  ['Skill data', 'سبق وتعاملت مع الاطفال اعداد ا...           الرياض
# 32                                      No requarment  المنطقة الشرقية
# 33                                      No requarment  المدينة المنورة
# 34                                      No requarment  المدينة المنورة
# 35                                      No requarment  المدينة المنورة
# 36                                      No requarment  المدينة المنورة
# 37                                      No requarment  المدينة المنورة
# 38  ['Skill data', 'مدخل بيانات ', 'محترف', 'Langu...  المدينة المنورة
# 39  ['Skill data', 'محاسبة  ', 'متوسط', 'Language ...  المنطقة الشرقية
# 40  ['Language data', 'العربية', 'محترف', 'الانجلي...  المنطقة الشرقية
# 41                                      No requarment           الباحة
# 42  ['Skill data', 'الاستقبال الفندقي', 'محترف', '...           الرياض
# 43                                      No requarment      مكة المكرمة
# 44  ['Skill data', 'اجادة الحاسب الالي', 'متوسط', ...           الرياض
# 45                                      No requarment  المنطقة الشرقية
# 46                                      No requarment           الرياض
# 47             ['Language data', 'العربية ', 'محترف']           الرياض
# 48                                  ['Language data']           الرياض
# 49                                  ['Language data']           الرياض
#
#             city                                           benefits  \
# 0   AR RIYADH...                               ['Salary', '5000.0']
# 1   AD DAMMAM...                               ['Salary', '5000.0']
# 2   ATH THUMA...                               ['Salary', '4000.0']
# 3    AL HUFUF...                               ['Salary', '5000.0']
# 4   AR RIYADH...                               ['Salary', '5000.0']
# 5   AR RIYADH...                               ['Salary', '4500.0']
# 6   AR RIYADH...                               ['Salary', '6000.0']
# 7   AR RIYADH...                               ['Salary', '8000.0']
# 8   AR RIYADH...                              ['Salary', '10000.0']
# 9   AR RIYADH...                               ['Salary', '5000.0']
# 10  AR RIYADH...  ['Salary', '7200.0', 'Benefits', 'بدل نقل 800 ...
# 11  AL BATALI...                               ['Salary', '4000.0']
# 12  AR RIYADH...  ['Salary', '7200.0', 'Benefits', 'بدل نقل 800 ...
# 13     JEDDAH...                               ['Salary', '6000.0']
# 14       HAIL...                               ['Salary', '7000.0']
# 15       HAIL...                               ['Salary', '3000.0']
# 16       HAIL...                               ['Salary', '9000.0']
# 17       HAIL...                              ['Salary', '12000.0']
# 18     JEDDAH...                               ['Salary', '4000.0']
# 19  MAKKAH AL...                               ['Salary', '5500.0']
# 20  AR RIYADH...                               ['Salary', '5000.0']
# 21  MAKKAH AL...                               ['Salary', '8400.0']
# 22  AR RIYADH...            ['Salary', '4000.0', 'Benefits', '500']
# 23  AR RIYADH...           ['Salary', '4000.0', 'Benefits', '2000']
# 24    GHITHAH...  ['Salary', '4000.0', 'Benefits', 'تأمين طبي حس...
# 25  AL MADINA...                               ['Salary', '4000.0']
# 26  AR RIYADH...  ['Salary', '4000.0', 'Benefits', '1000 حسب الخ...
# 27  ABA ASLAB...                               ['Salary', '6000.0']
# 28  AR RIYADH...                               ['Salary', '4500.0']
# 29  AR RIYADH...                               ['Salary', '5500.0']
# 30  AR RIYADH...        ['Salary', '4000.0', 'Benefits', '4000 SR']
# 31  AR RIYADH...      ['Salary', '3200.0', 'Benefits', '3200 ريال']
# 32  AD DAMMAM...  ['Salary', '5000.0', 'Benefits', '500 بدل نقل ...
# 33  AL MADINA...                               ['Salary', '7000.0']
# 34  AL MADINA...                               ['Salary', '7000.0']
# 35  AL MADINA...                               ['Salary', '7000.0']
# 36  AL MADINA...                               ['Salary', '4500.0']
# 37  AL MADINA...                               ['Salary', '4500.0']
# 38      YANBU...                               ['Salary', '4000.0']
# 39  AD DAMMAM...                               ['Salary', '4500.0']
# 40    DHAHRAN...  ['Salary', '4500.0', 'Benefits', 'حسب سنوات ال...
# 41    AL AQIQ...                               ['Salary', '4000.0']
# 42  AR RIYADH...  ['Salary', '4500.0', 'Benefits', 'تارقت شهري',...
# 43     JEDDAH...                               ['Salary', '5000.0']
# 44  AR RIYADH...                               ['Salary', '5500.0']
# 45  AD DAMMAM...  ['Salary', '4500.0', 'Benefits', 'اجازه يومين ...
# 46  ABA ASLAB...                               ['Salary', '4500.0']
# 47  AR RIYADH...                               ['Salary', '4000.0']
# 48  AR RIYADH...                               ['Salary', '4000.0']
# 49  AR RIYADH...                               ['Salary', '5000.0']
#
#       contract  positions     job_post_id  exper  gender   Salary
# 0    دوام كامل          1  20202026350419      0    Both   5000.0
# 1    دوام كامل          3  20202026350389      0    Both   5000.0
# 2    دوام كامل          2  20202026350347      2    Both   4000.0
# 3    دوام كامل         10  20202026350219      0    Male   5000.0
# 4    دوام كامل          1  20202026350043      0    Both   5000.0
# 5   عمل عن بعد          1  20202026350031      0    Both   4500.0
# 6    دوام كامل          2  20202026349999      4  Female   6000.0
# 7    دوام كامل          1  20202026349997      4  Female   8000.0
# 8    دوام كامل          3  20202026349992      2  Female  10000.0
# 9    دوام كامل          2  20202026349583      4  Female   5000.0
# 10   دوام كامل          4  20202026349578      0    Both   7200.0
# 11   دوام كامل          5  20202026349573      0    Both   4000.0
# 12   دوام كامل          4  20202026349572      0    Both   7200.0
# 13   دوام كامل          3  20202026349523      2  Female   6000.0
# 14   دوام كامل          1  20202026349504      4    Male   7000.0
# 15   دوام كامل          2  20202026349475      2    Male   3000.0
# 16   دوام كامل          1  20202026349439      4    Male   9000.0
# 17   دوام كامل          1  20202026349417     10    Male  12000.0
# 18   دوام كامل          1  20202026349390      2  Female   4000.0
# 19   دوام كامل          1  20202026349224      0  Female   5500.0
# 20   دوام كامل          1  20202026349216      0  Female   5000.0
# 21   دوام كامل          1  20202026348990      2    Male   8400.0
# 22   دوام كامل          1  20202026348866      2  Female   4000.0
# 23   دوام كامل          4  20202026348692      2    Both   4000.0
# 24   دوام كامل          1  20202026348685      0  Female   4000.0
# 25   دوام كامل          1  20202026348601      0    Male   4000.0
# 26   دوام كامل          1  20202026348520      0  Female   4000.0
# 27   دوام كامل          9  20202026348212      2  Female   6000.0
# 28   دوام كامل          1  20202026348193      4    Male   4500.0
# 29   دوام كامل          2  20202026348186      0    Both   5500.0
# 30   دوام كامل          2  20202026348103      2  Female   4000.0
# 31   دوام كامل          3  20202026348099      0  Female   3200.0
# 32   دوام كامل          1  20202026348009      4    Male   5000.0
# 33   دوام كامل          2  20202026347930      4    Male   7000.0
# 34   دوام كامل          2  20202026347926      4    Male   7000.0
# 35   دوام كامل          1  20202026347921      4    Male   7000.0
# 36   دوام كامل          2  20202026347913      0    Male   4500.0
# 37   دوام كامل          2  20202026347910      0    Male   4500.0
# 38   دوام كامل          1  20202026347907      0    Male   4000.0
# 39   دوام كامل          2  20202026347726      2    Both   4500.0
# 40   دوام كامل          1  20202026347650      2    Both   4500.0
# 41   دوام كامل          2  20202026347521      0  Female   4000.0
# 42   دوام كامل          4  20202026347394      2    Both   4500.0
# 43   دوام كامل          2  20202026347260      2    Both   5000.0
# 44   دوام كامل         10  20202026347254      0    Both   5500.0
# 45   دوام كامل          2  20202026346949      0    Both   4500.0
# 46   دوام كامل         10  20202026346948      0    Male   4500.0
# 47   دوام كامل         50  20202026346891      0    Male   4000.0
# 48   دوام كامل         10  20202026346879      2  Female   4000.0
# 49   دوام كامل          1  20202026346827      0  Female   5000.0

# %%
df.columns
# Out:
# Index(['job_title', 'job_date', 'job_desc', 'job_tasks', 'comp_name',
#        'comp_no', 'comp_type', 'comp_size', 'eco_activity', 'qualif', 'region',
#        'city', 'benefits', 'contract', 'positions', 'job_post_id', 'exper',
#        'gender', 'Salary'],
#       dtype='object')

# %%
df = df.drop(columns=['comp_no', 'job_post_id'])

# %%
df.columns
# Out:
# Index(['job_title', 'job_date', 'job_desc', 'job_tasks', 'comp_name',
#        'comp_type', 'comp_size', 'eco_activity', 'qualif', 'region', 'city',
#        'benefits', 'contract', 'positions', 'exper', 'gender', 'Salary'],
#       dtype='object')

# %%
new_column_names = {
    'job_title': 'Job Title',
    'job_date': 'Job Date',
    'job_desc': 'Job Description',
    'job_tasks': 'Job Tasks',
    'comp_name': 'Company Name',
    'comp_type': 'Company Type',
    'comp_size': 'Company Size',
    'eco_activity': 'Economic Activity',
    'qualif': 'Qualification',
    'region': 'Region',
    'city': 'City',
    'benefits': 'Benefits',
    'contract': 'Contract',
    'positions':'Number of vacancies',
    'exper': 'Experience / Yare',
    'gender': 'Gender',
    'Salary': 'Salary / SAR'
}
df.rename(columns=new_column_names, inplace=True)

# %%
df
# Out:
#                       Job Title    Job Date  \
# 0                         محاسب  27/05/1444
# 1                          بائع  27/05/1444
# 2     أخصائي عمليات موارد بشرية  27/05/1444
# 3               ميكانيكي سيارات  27/05/1444
# 4                         محاسب  27/05/1444
# ...                         ...         ...
# 1465        مهندس تقنية معلومات  19/06/1444
# 1466                     سكرتير  19/06/1444
# 1467                      صيدلي  18/06/1444
# 1468        مشغل آلة تشطيب رخام  18/06/1444
# 1469                      صيدلي  18/06/1444
#
#                                         Job Description  \
# 0     ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
# 1     ['بيع مجموعة من السلع والخدمات للعملاء، وتوفير...
# 2     ['تنفيذ الإجراءات والأنظمة والنماذج الخاصة بمر...
# 3     ['تشخيص أعطال السيارات وإصلاحها وتنفيذ برامج ا...
# 4     ['إعداد وتنظيم مستندات الصرف ومتابعة تحصيل الإ...
# ...                                                 ...
# 1465  ['دراسة احتياجات العميل من الأجهزة الحاسوبية و...
# 1466  ['دعم المدير أو الإدارة من خلال كتابة الوثائق ...
# 1467  ['دراسة التركيبات الدوائية للعقاقير والعلاجات ...
# 1468  ['تشغيل آلة تشطيب الرخام وابعادء الأجزاء المتف...
# 1469  ['دراسة التركيبات الدوائية للعقاقير والعلاجات ...
#
#                                               Job Tasks  \
# 0     ['   تدقيق المطالبات المالية والتأكد من اكتمال...
# 1     ['   بيع مجموعة من السلع والخدمات للعملاء.', '...
# 2     ['   تنفيذ الإجراءات والأنظمة والنماذج الخاصة ...
# 3     ['   فحص أداء المعدّات الكهربائية والميكانيكية...
# 4     ['   تدقيق المطالبات المالية والتأكد من اكتمال...
# ...                                                 ...
# 1465  ['   متابعة وتقييم عملية جمع وتحليل المعطيات و...
# 1466  ['   تدوين الملاحظات، التي يتم إملاؤها، بطريقة...
# 1467  ['   دراسة مواصفات وتركيبات الادوية والعقاقير ...
# 1468  ['   تسوية الرخام بواسطة أقراص الألماس الحديدي...
# 1469  ['   دراسة مواصفات وتركيبات الادوية والعقاقير ...
#
#                                            Company Name Company Type  \
# 0                              شركة مقر العالم للسفريات          خاص
# 1                          شركة عالم الكهرباء للمقاولات          خاص
# 2                                       شركه دار السلام          خاص
# 3                               مؤسسة لمكو لغيار الزيوت          خاص
# 4                          مؤسسة فكرة اليمامة للمقاولات          خاص
# ...                                                 ...          ...
# 1465                  مطعم الاوراق الخضر لتقديم الوجبات          خاص
# 1466         شركة ملتقى التجار لحاضنات و مسرعات الأعمال          خاص
# 1467                شركة تقنية الدواجن والألبان للتجارة          خاص
# 1468  مصنع عبدالرحمن بن محمد بن عبدالعزيز العبدالقاد...          خاص
# 1469                شركة تقنية الدواجن والألبان للتجارة          خاص
#
#       Company Size                                  Economic Activity  \
# 0     متوسطة فئة أ                        أنشطة وكالات السياحة والسفر
# 1     متوسطة فئة ب  تركيب انظمة التبريد وتكييف الهواء وصيانتها واص...
# 2     متوسطة فئة أ               ترميمات المباني السكنية والغير سكنية
# 3      صغيرة فئة ب                            مؤسسة لمكو لغيار الزيوت
# 4            كبيرة                   الإنشاءات العامة للمباني السكنية
# ...            ...                                                ...
# 1465   صغيرة فئة ب                                  المطاعم مع الخدمة
# 1466   صغيرة فئة ب                       أنشطة حاضنات ومسرعات الأعمال
# 1467   صغيرة فئة ب                شركة تقنية الدواجن والألبان للتجارة
# 1468   صغيرة فئة أ  مصنع عبدالرحمن بن محمد بن عبدالعزيز العبدالقاد...
# 1469   صغيرة فئة ب                شركة تقنية الدواجن والألبان للتجارة
#
#                                           Qualification           Region  \
# 0        ['Language data', 'اللغة الانجليزية', 'محترف']           الرياض
# 1                                         No requarment  المنطقة الشرقية
# 2              ['Language data', 'الانجليزيه', 'محترف']           الرياض
# 3     ['Skill data', 'صيانة السيارات وتقييم الاعطال'...  المنطقة الشرقية
# 4     ['Skill data', 'تحمل ضغط العمل', 'محترف', 'Lan...           الرياض
# ...                                                 ...              ...
# 1465                                      No requarment           الرياض
# 1466  ['Skill data', 'فن التواصل', 'محترف', 'Languag...      مكة المكرمة
# 1467  ['Professional certificate \\ License data', '...           الرياض
# 1468  ['Skill data', 'متقن للعمل وشغوف ويرغب بالتطور...  المنطقة الشرقية
# 1469  ['Professional certificate \\ License data', '...           الرياض
#
#               City                                           Benefits  \
# 0     AR RIYADH...                               ['Salary', '5000.0']
# 1     AD DAMMAM...                               ['Salary', '5000.0']
# 2     ATH THUMA...                               ['Salary', '4000.0']
# 3      AL HUFUF...                               ['Salary', '5000.0']
# 4     AR RIYADH...                               ['Salary', '5000.0']
# ...            ...                                                ...
# 1465  AR RIYADH...                               ['Salary', '5500.0']
# 1466     JEDDAH...                               ['Salary', '4000.0']
# 1467  AR RIYADH...                               ['Salary', '7000.0']
# 1468  AL KHUBAR...  ['Salary', '4000.0', 'Benefits', 'اجازة سنوية ...
# 1469  AR RIYADH...                               ['Salary', '7000.0']
#
#        Contract  Number of vacancies  Experience / Yare Gender  Salary / SAR
# 0     دوام كامل                    1                  0   Both        5000.0
# 1     دوام كامل                    3                  0   Both        5000.0
# 2     دوام كامل                    2                  2   Both        4000.0
# 3     دوام كامل                   10                  0   Male        5000.0
# 4     دوام كامل                    1                  0   Both        5000.0
# ...         ...                  ...                ...    ...           ...
# 1465  دوام كامل                    1                  0   Both        5500.0
# 1466  دوام كامل                    1                  2   Both        4000.0
# 1467  دوام كامل                    1                  0   Both        7000.0
# 1468  دوام كامل                    3                  0   Male        4000.0
# 1469  دوام كامل                    1                  0   Both        7000.0
#
# [1470 rows x 17 columns]

# %%
df.dtypes
# Out:
# Job Title               object
# Job Date                object
# Job Description         object
# Job Tasks               object
# Company Name            object
# Company Type            object
# Company Size            object
# Economic Activity       object
# Qualification           object
# Region                  object
# City                    object
# Benefits                object
# Contract                object
# Number of vacancies      int32
# Experience / Yare        int32
# Gender                  object
# Salary / SAR           float64
# dtype: object

# %%
df['Experience / Yare'].unique()
# Out:
# array([ 0,  2,  4, 10,  7, 12])

# %%
df['Salary / SAR'].unique()
# Out:
# array([ 5000.,  4000.,  4500.,  6000.,  8000., 10000.,  7200.,  7000.,
#         3000.,  9000., 12000.,  5500.,  8400.,  3200.,  4170.,  3640.,
#         5250.,  4400.,  4082.,  6150.,  6500., 15000., 16000.,  5700.,
#         4782.,  4375.,  4434., 13889.,  4444.,  4800.,  5625.,  9200.,
#         5600.,  8803.,  3500.,  5093.,  5800.,  5200.,  8500.,  3600.,
#         7500.,  4408., 27000.,  4083.,  4600.,  8496.,  6250.,  8333.,
#        32000., 12325.,  6583.,  5599.,  9500., 11000.,  4750.,  4320.,
#         4630.,  5066.,  4687.,  4625., 10250.,  5040.,  3198.,  4050.,
#         9600.,  4200., 35000., 13200.,  5271., 15532.,  4667.,  4300.,
#         4001.,  3300.,  5483.,  7757., 18000.,  6999.,  9900.,  4900.,
#        12400.,  9259., 14000.,  4100.,  5556.])

# %%
df['Salary / SAR'].max()
# Out:
# 35000.0

# %%
df['Salary / SAR'].min()
# Out:
# 3000.0

# %%
df['Number of vacancies'].unique()
# Out:
# array([ 1,  3,  2, 10,  4,  5,  9, 50,  6, 46,  8, 25, 20, 15,  7, 30])

# %%
def convert_to_gregorian(date_str):
    try:
        day, month, year = map(int, date_str.split('/'))
        gregorian_date = convert.Hijri(year, month, day).to_gregorian()
        return datetime(gregorian_date.year, gregorian_date.month, gregorian_date.day)
    except ValueError:
       
        return None

df['Job Date'] = df['Job Date'].apply(convert_to_gregorian)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[191], line 10
#       6     except ValueError:
#       8         return None
# ---> 10 df['Job Date'] = df['Job Date'].apply(convert_to_gregorian)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\base.py:919, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     916 arr = self._values
#     918 if isinstance(arr, ExtensionArray):
# --> 919     return arr.map(mapper, na_action=na_action)
#     921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arrays\_mixins.py:81, in ravel_compat.<locals>.method(self, *args, **kwargs)
#      78 @wraps(meth)
#      79 def method(self, *args, **kwargs):
#      80     if self.ndim == 1:
# ---> 81         return meth(self, *args, **kwargs)
#      83     flags = self._ndarray.flags
#      84     flat = self.ravel("K")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arrays\datetimelike.py:740, in DatetimeLikeArrayMixin.map(self, mapper, na_action)
#     736 @ravel_compat
#     737 def map(self, mapper, na_action=None):
#     738     from pandas import Index
# --> 740     result = map_array(self, mapper, na_action=na_action)
#     741     result = Index(result)
#     743     if isinstance(result, ABCMultiIndex):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[191], line 3, in convert_to_gregorian(date_str)
#       1 def convert_to_gregorian(date_str):
#       2     try:
# ----> 3         day, month, year = map(int, date_str.split('/'))
#       4         gregorian_date = convert.Hijri(year, month, day).to_gregorian()
#       5         return datetime(gregorian_date.year, gregorian_date.month, gregorian_date.day)
#
# AttributeError: 'Timestamp' object has no attribute 'split'

# %%
df['Job Date'] = pd.to_datetime(df['Job Date'], format='%d-%m-%Y')

# %%
df.dtypes
# Out:
# Job Title                      object
# Job Date               datetime64[ns]
# Job Description                object
# Job Tasks                      object
# Company Name                   object
# Company Type                   object
# Company Size                   object
# Economic Activity              object
# Qualification                  object
# Region                         object
# City                           object
# Benefits                       object
# Contract                       object
# Number of vacancies             int32
# Experience / Yare               int32
# Gender                         object
# Salary / SAR                  float64
# dtype: object

# %%
# go back to 7th dimension Accuracy

# %% [markdown]
# ### Dealing with outliers:

# %% [markdown]
# **How to remove Outliers?**
# Most of the ways to deal with outliers are similar to the methods of missing values like deleting rows, transforming them, binning them, treat them as a separate group, imputing values and other statistical methods. Here, we will discuss the common techniques used to deal with outliers:
#
# 1. Deleting rows: We delete outlier values if it is due to data entry error, data processing error or outlier rows are very small in numbers. We can also use trimming at both ends to remove outliers.
#
# 2. Imputing: Like imputation of missing values, we can also impute outliers. We can use mean, median, mode imputation methods. Before imputing values, we should analyse if it is natural outlier or artificial. If it is artificial, we can go with imputing values. We can also use statistical model to predict values of outlier rows and after that we can impute it with predicted values.
#
# 3. Treat separately: If there are significant number of outliers, we should treat them separately in the statistical model. One of the approach is to treat both groups as two different groups and build individual model for both groups and then combine the output.

# %%
condition = (df['Salary / SAR'] > 20000) & (df['Experience / Yare'] < 8)
df =df[~condition]

# %%
sns.histplot(data=df, 
            x="Experience / Yare",
             y = "Salary / SAR",
            )
# Out:
# <Axes: xlabel='Experience / Yare', ylabel='Salary / SAR'>

# %%
plt.figure(figsize=(15,8))
t10 = df.head(10)
sns.boxplot(
    df,
    x="Experience / Yare",
             y = "Salary / SAR",
    #z="Company Size"
)
# Out:
# <Axes: xlabel='Experience / Yare', ylabel='Salary / SAR'>

# %% [markdown]
# ## 3. Univariate Analysis:
#
# This involves examining single variables to understand their characteristics (distribution, central tendency, dispersion, and shape).
#
# We calculate **numerical values** about the data that tells us about the distribution of the data. We also **draw graphs** showing visually how the data is distributed. **To answer the following questions about Features/characteristics of Data:**
# - Where is the center of the data? (location)
# - How much does the data vary? (scale)
# - What is the shape of the data? (shape)
#
# **The benefits of this analysis:**
# Statistics summary gives a high-level idea to identify whether the data has any outliers, data entry error, distribution of data such as the data is normally distributed or left/right skewed
#
# **In this step, we will explore variables one by one using following approaches:**

# %% [markdown]
# ### 1. Univariate Graphical Analysis:
# Method to perform uni-variate analysis will depend on whether the variable type is categorical or numerical.

# %% [markdown]
# #### I. Categorical Variables:
#
# we’ll use frequency table to understand distribution of each category
# - Bar Chart (Ordinal) - Orderd
# - Pie Chart (Nominal) - non Orderd

# %% [markdown]
# #### II. Numerical Variables:
#
# we need to understand the central tendency and spread of the variable (Descriptive Analysis) using:
#    - Box plot
#    - Histogram

# %% [markdown]
# ### 2. Univariate Non-Graphical analysis:
#
# - Where is the center of the data? (location) --> **Measures of central tendency**
# - How much does the data vary? (scale) --> **Measure of variability**
# - What is the shape of the data? (shape) --> **Measures of variation combined with an average (measure of center) gives a good picture of the distribution of the data.**

# %% [markdown]
# ## 4. Bivariate/Multivariate Analysis:
#
# Here, you look at the relationships between two or more variables. This can involve looking for correlations, patterns, and trends that suggest a relationship or an association.
#
# We can perform bi-variate analysis for any combination of categorical and numerical variables. The combination can be:
# | bi-variate variables   | Plot type |
# | ------------- | ------------- |
# | Categorical & Categorical| Stacked Bar Chart |
# | Categorical & numerical  | scatter plot, histogram, box plot|
# | numerical  & numerical  | Scatter plot, line chart|
#
#
# Multivariate Analysis:
# - Heat map
# - Bar Chart
# - Scatter Chart
# - Line Chart

# %% [markdown]
# **Categorical & Categorical --> (Stacked Column Chart)**

# %% [markdown]
# **Categorical & numerical --> (scatter plot, histogram, box plot)**

# %% [markdown]
# **numerical & numerical --> (Scatter plot, line chart)**

# %% [markdown]
# We could also use a correlation matrix to get more specific information about the relationship between these two variables.
